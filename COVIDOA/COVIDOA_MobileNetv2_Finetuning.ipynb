# %%
# !pip install disarray
# Out:
# Collecting disarray
#   Downloading disarray-0.2.0-py2.py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: pandas>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from disarray) (2.1.4)
# Requirement already satisfied: numpy>=0.14.2 in /usr/local/lib/python3.10/dist-packages (from disarray) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23.0->disarray) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23.0->disarray) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23.0->disarray) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=0.23.0->disarray) (1.16.0)
# Downloading disarray-0.2.0-py2.py3-none-any.whl (6.8 kB)
# Installing collected packages: disarray
# Successfully installed disarray-0.2.0

# %%
import tensorflow
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import os
import shutil
from tqdm import tqdm
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import cv2
import sklearn
from sklearn.metrics import classification_report, confusion_matrix
import itertools
import disarray

# %%
def count_jpg_files(root_dir):
    """
    Count all .jpg files in the given directory and its subdirectories
    
    Args:
        root_dir (str): Path to the root directory to start searching from
        
    Returns:
        int: total count
    """
    total_count = 0
    dir_counts = {}
    
    # Walk through all directories
    for dirpath, dirnames, filenames in os.walk(root_dir):
        # Count jpg files in current directory
        jpg_count = len([f for f in filenames if f.lower().endswith('.jpg')])
        total_count += jpg_count
    
    return total_count

# %%
train_path = '/kaggle/input/multiclasscovidoasegmentedimages/covidoa_segmented_images/train_directory'
validation_path = '/kaggle/input/multiclasscovidoasegmentedimages/covidoa_segmented_images/validation_directory'
test_path = '/kaggle/input/multiclasscovidoasegmentedimages/covidoa_segmented_images/test_directory'

# %%
preprocess_input = tensorflow.keras.applications.mobilenet_v2.preprocess_input

image_gen = ImageDataGenerator(preprocessing_function=preprocess_input)

# %%
batch_size = 64
train_image_gen = image_gen.flow_from_directory(train_path, 
                                          target_size=(224,224), 
                                          color_mode='rgb',
                                          batch_size=batch_size,
                                          class_mode='categorical')

val_image_gen = image_gen.flow_from_directory(validation_path, 
                                          target_size=(224,224), 
                                          color_mode='rgb',
                                          batch_size=batch_size,
                                          class_mode='categorical',
                                          shuffle=False)

test_image_gen = image_gen.flow_from_directory(test_path, 
                                          target_size=(224,224), 
                                          color_mode='rgb',
                                          batch_size=batch_size,
                                          class_mode='categorical',
                                          shuffle=False)

print(test_image_gen.class_indices)
# Out:
# Found 36927 images belonging to 7 classes.
# Found 883 images belonging to 7 classes.
# Found 1103 images belonging to 7 classes.
# {'akiec': 0, 'bcc': 1, 'bkl': 2, 'df': 3, 'mel': 4, 'nv': 5, 'vasc': 6}

# %%
from tensorflow.keras.applications import *
from tensorflow.keras.layers import Dense, Input, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

for layer in base_model.layers:
    layer.trainable = True

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128,kernel_regularizer='l2',activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(7, activation='softmax')(x)
tl_model = Model(inputs=base_model.input, outputs=x)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
base_model.summary()
# Out:
# Model: "mobilenetv2_1.00_224"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 224, 224, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv1 (Conv2D)            │ (None, 112, 112, 32)   │            864 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bn_Conv1                  │ (None, 112, 112, 32)   │            128 │ Conv1[0][0]            │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv1_relu (ReLU)         │ (None, 112, 112, 32)   │              0 │ bn_Conv1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise   │ (None, 112, 112, 32)   │            288 │ Conv1_relu[0][0]       │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise_… │ (None, 112, 112, 32)   │            128 │ expanded_conv_depthwi… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise_… │ (None, 112, 112, 32)   │              0 │ expanded_conv_depthwi… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_project     │ (None, 112, 112, 16)   │            512 │ expanded_conv_depthwi… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_project_BN  │ (None, 112, 112, 16)   │             64 │ expanded_conv_project… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand (Conv2D)   │ (None, 112, 112, 96)   │          1,536 │ expanded_conv_project… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand_BN         │ (None, 112, 112, 96)   │            384 │ block_1_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand_relu       │ (None, 112, 112, 96)   │              0 │ block_1_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_pad               │ (None, 113, 113, 96)   │              0 │ block_1_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise         │ (None, 56, 56, 96)     │            864 │ block_1_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise_BN      │ (None, 56, 56, 96)     │            384 │ block_1_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise_relu    │ (None, 56, 56, 96)     │              0 │ block_1_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_project (Conv2D)  │ (None, 56, 56, 24)     │          2,304 │ block_1_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_project_BN        │ (None, 56, 56, 24)     │             96 │ block_1_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand (Conv2D)   │ (None, 56, 56, 144)    │          3,456 │ block_1_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand_BN         │ (None, 56, 56, 144)    │            576 │ block_2_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand_relu       │ (None, 56, 56, 144)    │              0 │ block_2_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise         │ (None, 56, 56, 144)    │          1,296 │ block_2_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise_BN      │ (None, 56, 56, 144)    │            576 │ block_2_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise_relu    │ (None, 56, 56, 144)    │              0 │ block_2_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_project (Conv2D)  │ (None, 56, 56, 24)     │          3,456 │ block_2_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_project_BN        │ (None, 56, 56, 24)     │             96 │ block_2_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_add (Add)         │ (None, 56, 56, 24)     │              0 │ block_1_project_BN[0]… │
# │                           │                        │                │ block_2_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand (Conv2D)   │ (None, 56, 56, 144)    │          3,456 │ block_2_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand_BN         │ (None, 56, 56, 144)    │            576 │ block_3_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand_relu       │ (None, 56, 56, 144)    │              0 │ block_3_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_pad               │ (None, 57, 57, 144)    │              0 │ block_3_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise         │ (None, 28, 28, 144)    │          1,296 │ block_3_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise_BN      │ (None, 28, 28, 144)    │            576 │ block_3_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise_relu    │ (None, 28, 28, 144)    │              0 │ block_3_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_project (Conv2D)  │ (None, 28, 28, 32)     │          4,608 │ block_3_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_project_BN        │ (None, 28, 28, 32)     │            128 │ block_3_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand (Conv2D)   │ (None, 28, 28, 192)    │          6,144 │ block_3_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand_BN         │ (None, 28, 28, 192)    │            768 │ block_4_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand_relu       │ (None, 28, 28, 192)    │              0 │ block_4_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise         │ (None, 28, 28, 192)    │          1,728 │ block_4_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise_BN      │ (None, 28, 28, 192)    │            768 │ block_4_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise_relu    │ (None, 28, 28, 192)    │              0 │ block_4_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_project (Conv2D)  │ (None, 28, 28, 32)     │          6,144 │ block_4_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_project_BN        │ (None, 28, 28, 32)     │            128 │ block_4_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_add (Add)         │ (None, 28, 28, 32)     │              0 │ block_3_project_BN[0]… │
# │                           │                        │                │ block_4_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand (Conv2D)   │ (None, 28, 28, 192)    │          6,144 │ block_4_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand_BN         │ (None, 28, 28, 192)    │            768 │ block_5_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand_relu       │ (None, 28, 28, 192)    │              0 │ block_5_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise         │ (None, 28, 28, 192)    │          1,728 │ block_5_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise_BN      │ (None, 28, 28, 192)    │            768 │ block_5_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise_relu    │ (None, 28, 28, 192)    │              0 │ block_5_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_project (Conv2D)  │ (None, 28, 28, 32)     │          6,144 │ block_5_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_project_BN        │ (None, 28, 28, 32)     │            128 │ block_5_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_add (Add)         │ (None, 28, 28, 32)     │              0 │ block_4_add[0][0],     │
# │                           │                        │                │ block_5_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand (Conv2D)   │ (None, 28, 28, 192)    │          6,144 │ block_5_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand_BN         │ (None, 28, 28, 192)    │            768 │ block_6_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand_relu       │ (None, 28, 28, 192)    │              0 │ block_6_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_pad               │ (None, 29, 29, 192)    │              0 │ block_6_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise         │ (None, 14, 14, 192)    │          1,728 │ block_6_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise_BN      │ (None, 14, 14, 192)    │            768 │ block_6_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise_relu    │ (None, 14, 14, 192)    │              0 │ block_6_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_project (Conv2D)  │ (None, 14, 14, 64)     │         12,288 │ block_6_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_project_BN        │ (None, 14, 14, 64)     │            256 │ block_6_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand (Conv2D)   │ (None, 14, 14, 384)    │         24,576 │ block_6_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand_BN         │ (None, 14, 14, 384)    │          1,536 │ block_7_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand_relu       │ (None, 14, 14, 384)    │              0 │ block_7_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise         │ (None, 14, 14, 384)    │          3,456 │ block_7_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise_BN      │ (None, 14, 14, 384)    │          1,536 │ block_7_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise_relu    │ (None, 14, 14, 384)    │              0 │ block_7_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_project (Conv2D)  │ (None, 14, 14, 64)     │         24,576 │ block_7_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_project_BN        │ (None, 14, 14, 64)     │            256 │ block_7_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_add (Add)         │ (None, 14, 14, 64)     │              0 │ block_6_project_BN[0]… │
# │                           │                        │                │ block_7_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand (Conv2D)   │ (None, 14, 14, 384)    │         24,576 │ block_7_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand_BN         │ (None, 14, 14, 384)    │          1,536 │ block_8_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand_relu       │ (None, 14, 14, 384)    │              0 │ block_8_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise         │ (None, 14, 14, 384)    │          3,456 │ block_8_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise_BN      │ (None, 14, 14, 384)    │          1,536 │ block_8_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise_relu    │ (None, 14, 14, 384)    │              0 │ block_8_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_project (Conv2D)  │ (None, 14, 14, 64)     │         24,576 │ block_8_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_project_BN        │ (None, 14, 14, 64)     │            256 │ block_8_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_add (Add)         │ (None, 14, 14, 64)     │              0 │ block_7_add[0][0],     │
# │                           │                        │                │ block_8_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand (Conv2D)   │ (None, 14, 14, 384)    │         24,576 │ block_8_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand_BN         │ (None, 14, 14, 384)    │          1,536 │ block_9_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand_relu       │ (None, 14, 14, 384)    │              0 │ block_9_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise         │ (None, 14, 14, 384)    │          3,456 │ block_9_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise_BN      │ (None, 14, 14, 384)    │          1,536 │ block_9_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise_relu    │ (None, 14, 14, 384)    │              0 │ block_9_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_project (Conv2D)  │ (None, 14, 14, 64)     │         24,576 │ block_9_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_project_BN        │ (None, 14, 14, 64)     │            256 │ block_9_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_add (Add)         │ (None, 14, 14, 64)     │              0 │ block_8_add[0][0],     │
# │                           │                        │                │ block_9_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand (Conv2D)  │ (None, 14, 14, 384)    │         24,576 │ block_9_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand_BN        │ (None, 14, 14, 384)    │          1,536 │ block_10_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand_relu      │ (None, 14, 14, 384)    │              0 │ block_10_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise        │ (None, 14, 14, 384)    │          3,456 │ block_10_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise_BN     │ (None, 14, 14, 384)    │          1,536 │ block_10_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise_relu   │ (None, 14, 14, 384)    │              0 │ block_10_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_project (Conv2D) │ (None, 14, 14, 96)     │         36,864 │ block_10_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_project_BN       │ (None, 14, 14, 96)     │            384 │ block_10_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand (Conv2D)  │ (None, 14, 14, 576)    │         55,296 │ block_10_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand_BN        │ (None, 14, 14, 576)    │          2,304 │ block_11_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand_relu      │ (None, 14, 14, 576)    │              0 │ block_11_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise        │ (None, 14, 14, 576)    │          5,184 │ block_11_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise_BN     │ (None, 14, 14, 576)    │          2,304 │ block_11_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise_relu   │ (None, 14, 14, 576)    │              0 │ block_11_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_project (Conv2D) │ (None, 14, 14, 96)     │         55,296 │ block_11_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_project_BN       │ (None, 14, 14, 96)     │            384 │ block_11_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_add (Add)        │ (None, 14, 14, 96)     │              0 │ block_10_project_BN[0… │
# │                           │                        │                │ block_11_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand (Conv2D)  │ (None, 14, 14, 576)    │         55,296 │ block_11_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand_BN        │ (None, 14, 14, 576)    │          2,304 │ block_12_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand_relu      │ (None, 14, 14, 576)    │              0 │ block_12_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise        │ (None, 14, 14, 576)    │          5,184 │ block_12_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise_BN     │ (None, 14, 14, 576)    │          2,304 │ block_12_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise_relu   │ (None, 14, 14, 576)    │              0 │ block_12_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_project (Conv2D) │ (None, 14, 14, 96)     │         55,296 │ block_12_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_project_BN       │ (None, 14, 14, 96)     │            384 │ block_12_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_add (Add)        │ (None, 14, 14, 96)     │              0 │ block_11_add[0][0],    │
# │                           │                        │                │ block_12_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand (Conv2D)  │ (None, 14, 14, 576)    │         55,296 │ block_12_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand_BN        │ (None, 14, 14, 576)    │          2,304 │ block_13_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand_relu      │ (None, 14, 14, 576)    │              0 │ block_13_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_pad              │ (None, 15, 15, 576)    │              0 │ block_13_expand_relu[… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise        │ (None, 7, 7, 576)      │          5,184 │ block_13_pad[0][0]     │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise_BN     │ (None, 7, 7, 576)      │          2,304 │ block_13_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise_relu   │ (None, 7, 7, 576)      │              0 │ block_13_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_project (Conv2D) │ (None, 7, 7, 160)      │         92,160 │ block_13_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_project_BN       │ (None, 7, 7, 160)      │            640 │ block_13_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand (Conv2D)  │ (None, 7, 7, 960)      │        153,600 │ block_13_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand_BN        │ (None, 7, 7, 960)      │          3,840 │ block_14_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand_relu      │ (None, 7, 7, 960)      │              0 │ block_14_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise        │ (None, 7, 7, 960)      │          8,640 │ block_14_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise_BN     │ (None, 7, 7, 960)      │          3,840 │ block_14_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise_relu   │ (None, 7, 7, 960)      │              0 │ block_14_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_project (Conv2D) │ (None, 7, 7, 160)      │        153,600 │ block_14_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_project_BN       │ (None, 7, 7, 160)      │            640 │ block_14_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_add (Add)        │ (None, 7, 7, 160)      │              0 │ block_13_project_BN[0… │
# │                           │                        │                │ block_14_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand (Conv2D)  │ (None, 7, 7, 960)      │        153,600 │ block_14_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand_BN        │ (None, 7, 7, 960)      │          3,840 │ block_15_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand_relu      │ (None, 7, 7, 960)      │              0 │ block_15_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise        │ (None, 7, 7, 960)      │          8,640 │ block_15_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise_BN     │ (None, 7, 7, 960)      │          3,840 │ block_15_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise_relu   │ (None, 7, 7, 960)      │              0 │ block_15_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_project (Conv2D) │ (None, 7, 7, 160)      │        153,600 │ block_15_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_project_BN       │ (None, 7, 7, 160)      │            640 │ block_15_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_add (Add)        │ (None, 7, 7, 160)      │              0 │ block_14_add[0][0],    │
# │                           │                        │                │ block_15_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand (Conv2D)  │ (None, 7, 7, 960)      │        153,600 │ block_15_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand_BN        │ (None, 7, 7, 960)      │          3,840 │ block_16_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand_relu      │ (None, 7, 7, 960)      │              0 │ block_16_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise        │ (None, 7, 7, 960)      │          8,640 │ block_16_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise_BN     │ (None, 7, 7, 960)      │          3,840 │ block_16_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise_relu   │ (None, 7, 7, 960)      │              0 │ block_16_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_project (Conv2D) │ (None, 7, 7, 320)      │        307,200 │ block_16_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_project_BN       │ (None, 7, 7, 320)      │          1,280 │ block_16_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv_1 (Conv2D)           │ (None, 7, 7, 1280)     │        409,600 │ block_16_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv_1_bn                 │ (None, 7, 7, 1280)     │          5,120 │ Conv_1[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ out_relu (ReLU)           │ (None, 7, 7, 1280)     │              0 │ Conv_1_bn[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 2,257,984 (8.61 MB)
#  Trainable params: 2,223,872 (8.48 MB)
#  Non-trainable params: 34,112 (133.25 KB)

# %%
from tensorflow.keras import backend as K
from tensorflow.keras.metrics import categorical_accuracy, top_k_categorical_accuracy

def top_3_accuracy(y_true, y_pred):
    return top_k_categorical_accuracy(y_true, y_pred, k=3)

def top_2_accuracy(y_true, y_pred):
    return top_k_categorical_accuracy(y_true, y_pred, k=2)

def precision(y_true, y_pred):
    """Precision metric.
    Only computes a batch-wise average of precision.
    Computes the precision, a metric for multi-label classification of
    how many selected items are relevant.
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision_value = true_positives / (predicted_positives + K.epsilon())
    return precision_value

def recall(y_true, y_pred):
    """Recall metric.
    Only computes a batch-wise average of recall.
    Computes the recall, a metric for multi-label classification of
    how many relevant items are selected.
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall_value = true_positives / (possible_positives + K.epsilon())
    return recall_value

def f1_score(y_true, y_pred):
    precision_value = precision(y_true, y_pred)
    recall_value = recall(y_true, y_pred)
    f1_score_value = 2*((precision_value*recall_value)/(precision_value+recall_value+K.epsilon()))
    return f1_score_value

# %%
optimizer = Adam(0.0001)
tl_model.compile(loss="categorical_crossentropy", optimizer=optimizer, metrics=[categorical_accuracy, top_2_accuracy, top_3_accuracy, precision, recall, f1_score])

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint

lr_reduce = ReduceLROnPlateau(
    monitor='val_categorical_accuracy',
    factor=0.5,
    patience=3,        
    mode='max',
    min_lr=0.00001,
    verbose=1
)

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=10,       
    mode='min',
    restore_best_weights=True,
    verbose=1
)

model_chkpt = ModelCheckpoint(
    "best_model.keras",
    save_best_only=True,
    monitor='val_categorical_accuracy',
    mode='max',
    verbose=1
)

callback_list = [model_chkpt, lr_reduce, early_stop]

# %%
total_samples = sum([5115, 5950, 5990, 5462, 5510, 4810, 4090])
class_weights = {
    0: total_samples / 5510,
    1: total_samples / 5462,
    2: total_samples / 5990,
    3: total_samples / 4090,
    4: total_samples / 5950,
    5: total_samples / 5115,
    6: total_samples / 4810
}

# %%
history = tl_model.fit(train_image_gen,
                       epochs=30, 
                       validation_data = val_image_gen,
                       class_weight=class_weights,
                       callbacks=callback_list)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - categorical_accuracy: 0.4958 - f1_score: 0.4172 - loss: 11.4565 - precision: 0.6752 - recall: 0.3157 - top_2_accuracy: 0.6832 - top_3_accuracy: 0.8026
# Epoch 1: val_categorical_accuracy improved from -inf to 0.55040, saving model to best_model.keras
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 292s 406ms/step - categorical_accuracy: 0.4959 - f1_score: 0.4174 - loss: 11.4534 - precision: 0.6753 - recall: 0.3159 - top_2_accuracy: 0.6833 - top_3_accuracy: 0.8028 - val_categorical_accuracy: 0.5504 - val_f1_score: 0.5545 - val_loss: 3.4680 - val_precision: 0.5935 - val_recall: 0.5216 - val_top_2_accuracy: 0.7803 - val_top_3_accuracy: 0.8596 - learning_rate: 1.0000e-04
# Epoch 2/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - categorical_accuracy: 0.7187 - f1_score: 0.6997 - loss: 7.0701 - precision: 0.8057 - recall: 0.6196 - top_2_accuracy: 0.8851 - top_3_accuracy: 0.9555
# Epoch 2: val_categorical_accuracy improved from 0.55040 to 0.64892, saving model to best_model.keras
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 119s 203ms/step - categorical_accuracy: 0.7187 - f1_score: 0.6997 - loss: 7.0697 - precision: 0.8057 - recall: 0.6197 - top_2_accuracy: 0.8851 - top_3_accuracy: 0.9555 - val_categorical_accuracy: 0.6489 - val_f1_score: 0.6368 - val_loss: 3.0368 - val_precision: 0.6669 - val_recall: 0.6110 - val_top_2_accuracy: 0.8709 - val_top_3_accuracy: 0.9434 - learning_rate: 1.0000e-04
# Epoch 3/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - categorical_accuracy: 0.7959 - f1_score: 0.7878 - loss: 5.4783 - precision: 0.8513 - recall: 0.7338 - top_2_accuracy: 0.9304 - top_3_accuracy: 0.9763
# Epoch 3: val_categorical_accuracy improved from 0.64892 to 0.83692, saving model to best_model.keras
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 113s 194ms/step - categorical_accuracy: 0.7959 - f1_score: 0.7878 - loss: 5.4781 - precision: 0.8513 - recall: 0.7338 - top_2_accuracy: 0.9304 - top_3_accuracy: 0.9763 - val_categorical_accuracy: 0.8369 - val_f1_score: 0.8244 - val_loss: 2.2284 - val_precision: 0.8465 - val_recall: 0.8058 - val_top_2_accuracy: 0.9354 - val_top_3_accuracy: 0.9728 - learning_rate: 1.0000e-04
# Epoch 4/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - categorical_accuracy: 0.8435 - f1_score: 0.8404 - loss: 4.4439 - precision: 0.8808 - recall: 0.8043 - top_2_accuracy: 0.9535 - top_3_accuracy: 0.9852
# Epoch 4: val_categorical_accuracy improved from 0.83692 to 0.85730, saving model to best_model.keras
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 112s 192ms/step - categorical_accuracy: 0.8435 - f1_score: 0.8404 - loss: 4.4438 - precision: 0.8808 - recall: 0.8043 - top_2_accuracy: 0.9535 - top_3_accuracy: 0.9852 - val_categorical_accuracy: 0.8573 - val_f1_score: 0.8513 - val_loss: 2.0065 - val_precision: 0.8710 - val_recall: 0.8342 - val_top_2_accuracy: 0.9479 - val_top_3_accuracy: 0.9785 - learning_rate: 1.0000e-04
# Epoch 5/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - categorical_accuracy: 0.8850 - f1_score: 0.8855 - loss: 3.5655 - precision: 0.9117 - recall: 0.8613 - top_2_accuracy: 0.9716 - top_3_accuracy: 0.9921
# Epoch 5: val_categorical_accuracy improved from 0.85730 to 0.86297, saving model to best_model.keras
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 111s 190ms/step - categorical_accuracy: 0.8850 - f1_score: 0.8855 - loss: 3.5655 - precision: 0.9117 - recall: 0.8613 - top_2_accuracy: 0.9716 - top_3_accuracy: 0.9921 - val_categorical_accuracy: 0.8630 - val_f1_score: 0.8578 - val_loss: 1.8147 - val_precision: 0.8717 - val_recall: 0.8457 - val_top_2_accuracy: 0.9581 - val_top_3_accuracy: 0.9785 - learning_rate: 1.0000e-04
# Epoch 6/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - categorical_accuracy: 0.9174 - f1_score: 0.9157 - loss: 2.8673 - precision: 0.9314 - recall: 0.9008 - top_2_accuracy: 0.9831 - top_3_accuracy: 0.9958
# Epoch 6: val_categorical_accuracy improved from 0.86297 to 0.86410, saving model to best_model.keras
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 113s 193ms/step - categorical_accuracy: 0.9174 - f1_score: 0.9157 - loss: 2.8673 - precision: 0.9314 - recall: 0.9008 - top_2_accuracy: 0.9831 - top_3_accuracy: 0.9958 - val_categorical_accuracy: 0.8641 - val_f1_score: 0.8640 - val_loss: 1.7197 - val_precision: 0.8715 - val_recall: 0.8574 - val_top_2_accuracy: 0.9434 - val_top_3_accuracy: 0.9717 - learning_rate: 1.0000e-04
# Epoch 7/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - categorical_accuracy: 0.9406 - f1_score: 0.9404 - loss: 2.3525 - precision: 0.9504 - recall: 0.9307 - top_2_accuracy: 0.9886 - top_3_accuracy: 0.9972
# Epoch 7: val_categorical_accuracy did not improve from 0.86410
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 119s 204ms/step - categorical_accuracy: 0.9405 - f1_score: 0.9404 - loss: 2.3526 - precision: 0.9504 - recall: 0.9307 - top_2_accuracy: 0.9886 - top_3_accuracy: 0.9972 - val_categorical_accuracy: 0.8131 - val_f1_score: 0.8126 - val_loss: 1.8915 - val_precision: 0.8186 - val_recall: 0.8069 - val_top_2_accuracy: 0.9264 - val_top_3_accuracy: 0.9694 - learning_rate: 1.0000e-04
# Epoch 8/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - categorical_accuracy: 0.9518 - f1_score: 0.9517 - loss: 1.9710 - precision: 0.9585 - recall: 0.9451 - top_2_accuracy: 0.9925 - top_3_accuracy: 0.9981
# Epoch 8: val_categorical_accuracy did not improve from 0.86410
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 118s 202ms/step - categorical_accuracy: 0.9518 - f1_score: 0.9517 - loss: 1.9711 - precision: 0.9585 - recall: 0.9451 - top_2_accuracy: 0.9925 - top_3_accuracy: 0.9981 - val_categorical_accuracy: 0.8596 - val_f1_score: 0.8559 - val_loss: 1.6149 - val_precision: 0.8602 - val_recall: 0.8518 - val_top_2_accuracy: 0.9309 - val_top_3_accuracy: 0.9672 - learning_rate: 1.0000e-04
# Epoch 9/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - categorical_accuracy: 0.9590 - f1_score: 0.9595 - loss: 1.7126 - precision: 0.9642 - recall: 0.9550 - top_2_accuracy: 0.9947 - top_3_accuracy: 0.9988
# Epoch 9: val_categorical_accuracy did not improve from 0.86410
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 114s 195ms/step - categorical_accuracy: 0.9590 - f1_score: 0.9595 - loss: 1.7127 - precision: 0.9642 - recall: 0.9550 - top_2_accuracy: 0.9947 - top_3_accuracy: 0.9988 - val_categorical_accuracy: 0.8177 - val_f1_score: 0.8169 - val_loss: 1.6584 - val_precision: 0.8227 - val_recall: 0.8113 - val_top_2_accuracy: 0.9241 - val_top_3_accuracy: 0.9638 - learning_rate: 1.0000e-04
# Epoch 10/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - categorical_accuracy: 0.9779 - f1_score: 0.9782 - loss: 1.2794 - precision: 0.9813 - recall: 0.9752 - top_2_accuracy: 0.9977 - top_3_accuracy: 0.9994
# Epoch 10: val_categorical_accuracy did not improve from 0.86410
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 114s 196ms/step - categorical_accuracy: 0.9779 - f1_score: 0.9782 - loss: 1.2793 - precision: 0.9813 - recall: 0.9752 - top_2_accuracy: 0.9977 - top_3_accuracy: 0.9994 - val_categorical_accuracy: 0.8290 - val_f1_score: 0.8327 - val_loss: 1.5280 - val_precision: 0.8351 - val_recall: 0.8303 - val_top_2_accuracy: 0.9468 - val_top_3_accuracy: 0.9807 - learning_rate: 5.0000e-05
# Epoch 11/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - categorical_accuracy: 0.9888 - f1_score: 0.9892 - loss: 1.0049 - precision: 0.9903 - recall: 0.9882 - top_2_accuracy: 0.9992 - top_3_accuracy: 0.9999
# Epoch 11: val_categorical_accuracy improved from 0.86410 to 0.87089, saving model to best_model.keras
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 113s 194ms/step - categorical_accuracy: 0.9888 - f1_score: 0.9892 - loss: 1.0049 - precision: 0.9903 - recall: 0.9882 - top_2_accuracy: 0.9992 - top_3_accuracy: 0.9999 - val_categorical_accuracy: 0.8709 - val_f1_score: 0.8697 - val_loss: 1.4715 - val_precision: 0.8721 - val_recall: 0.8675 - val_top_2_accuracy: 0.9513 - val_top_3_accuracy: 0.9773 - learning_rate: 5.0000e-05
# Epoch 12/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - categorical_accuracy: 0.9901 - f1_score: 0.9904 - loss: 0.9199 - precision: 0.9911 - recall: 0.9896 - top_2_accuracy: 0.9993 - top_3_accuracy: 0.9999
# Epoch 12: val_categorical_accuracy did not improve from 0.87089
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 111s 190ms/step - categorical_accuracy: 0.9901 - f1_score: 0.9903 - loss: 0.9199 - precision: 0.9911 - recall: 0.9896 - top_2_accuracy: 0.9993 - top_3_accuracy: 0.9999 - val_categorical_accuracy: 0.8607 - val_f1_score: 0.8600 - val_loss: 1.4321 - val_precision: 0.8624 - val_recall: 0.8577 - val_top_2_accuracy: 0.9468 - val_top_3_accuracy: 0.9773 - learning_rate: 5.0000e-05
# Epoch 13/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - categorical_accuracy: 0.9900 - f1_score: 0.9901 - loss: 0.8660 - precision: 0.9910 - recall: 0.9893 - top_2_accuracy: 0.9989 - top_3_accuracy: 1.0000
# Epoch 13: val_categorical_accuracy improved from 0.87089 to 0.87542, saving model to best_model.keras
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 115s 197ms/step - categorical_accuracy: 0.9900 - f1_score: 0.9901 - loss: 0.8660 - precision: 0.9910 - recall: 0.9893 - top_2_accuracy: 0.9989 - top_3_accuracy: 1.0000 - val_categorical_accuracy: 0.8754 - val_f1_score: 0.8767 - val_loss: 1.3455 - val_precision: 0.8778 - val_recall: 0.8755 - val_top_2_accuracy: 0.9468 - val_top_3_accuracy: 0.9853 - learning_rate: 5.0000e-05
# Epoch 14/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - categorical_accuracy: 0.9911 - f1_score: 0.9912 - loss: 0.7712 - precision: 0.9920 - recall: 0.9905 - top_2_accuracy: 0.9993 - top_3_accuracy: 0.9999
# Epoch 14: val_categorical_accuracy did not improve from 0.87542
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 113s 194ms/step - categorical_accuracy: 0.9911 - f1_score: 0.9912 - loss: 0.7712 - precision: 0.9920 - recall: 0.9905 - top_2_accuracy: 0.9993 - top_3_accuracy: 0.9999 - val_categorical_accuracy: 0.8482 - val_f1_score: 0.8487 - val_loss: 1.2925 - val_precision: 0.8500 - val_recall: 0.8473 - val_top_2_accuracy: 0.9513 - val_top_3_accuracy: 0.9807 - learning_rate: 5.0000e-05
# Epoch 15/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - categorical_accuracy: 0.9931 - f1_score: 0.9932 - loss: 0.6735 - precision: 0.9938 - recall: 0.9927 - top_2_accuracy: 0.9996 - top_3_accuracy: 0.9999
# Epoch 15: val_categorical_accuracy did not improve from 0.87542
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 113s 193ms/step - categorical_accuracy: 0.9931 - f1_score: 0.9932 - loss: 0.6735 - precision: 0.9938 - recall: 0.9927 - top_2_accuracy: 0.9996 - top_3_accuracy: 0.9999 - val_categorical_accuracy: 0.8505 - val_f1_score: 0.8532 - val_loss: 1.1943 - val_precision: 0.8564 - val_recall: 0.8501 - val_top_2_accuracy: 0.9547 - val_top_3_accuracy: 0.9796 - learning_rate: 5.0000e-05
# Epoch 16/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - categorical_accuracy: 0.9898 - f1_score: 0.9896 - loss: 0.6751 - precision: 0.9902 - recall: 0.9890 - top_2_accuracy: 0.9995 - top_3_accuracy: 0.9999
# Epoch 16: val_categorical_accuracy did not improve from 0.87542
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 111s 190ms/step - categorical_accuracy: 0.9898 - f1_score: 0.9896 - loss: 0.6751 - precision: 0.9902 - recall: 0.9890 - top_2_accuracy: 0.9995 - top_3_accuracy: 0.9999 - val_categorical_accuracy: 0.8596 - val_f1_score: 0.8606 - val_loss: 1.3097 - val_precision: 0.8621 - val_recall: 0.8591 - val_top_2_accuracy: 0.9388 - val_top_3_accuracy: 0.9785 - learning_rate: 5.0000e-05
# Epoch 17/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - categorical_accuracy: 0.9964 - f1_score: 0.9964 - loss: 0.5310 - precision: 0.9965 - recall: 0.9962 - top_2_accuracy: 0.9997 - top_3_accuracy: 0.9999
# Epoch 17: val_categorical_accuracy did not improve from 0.87542
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 112s 191ms/step - categorical_accuracy: 0.9964 - f1_score: 0.9964 - loss: 0.5309 - precision: 0.9965 - recall: 0.9962 - top_2_accuracy: 0.9997 - top_3_accuracy: 0.9999 - val_categorical_accuracy: 0.8698 - val_f1_score: 0.8725 - val_loss: 1.1558 - val_precision: 0.8737 - val_recall: 0.8714 - val_top_2_accuracy: 0.9479 - val_top_3_accuracy: 0.9796 - learning_rate: 2.5000e-05
# Epoch 18/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - categorical_accuracy: 0.9974 - f1_score: 0.9973 - loss: 0.4612 - precision: 0.9975 - recall: 0.9971 - top_2_accuracy: 1.0000 - top_3_accuracy: 1.0000
# Epoch 18: val_categorical_accuracy did not improve from 0.87542
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 115s 198ms/step - categorical_accuracy: 0.9974 - f1_score: 0.9973 - loss: 0.4612 - precision: 0.9975 - recall: 0.9971 - top_2_accuracy: 1.0000 - top_3_accuracy: 1.0000 - val_categorical_accuracy: 0.8618 - val_f1_score: 0.8642 - val_loss: 1.1015 - val_precision: 0.8668 - val_recall: 0.8616 - val_top_2_accuracy: 0.9547 - val_top_3_accuracy: 0.9785 - learning_rate: 2.5000e-05
# Epoch 19/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - categorical_accuracy: 0.9979 - f1_score: 0.9978 - loss: 0.4285 - precision: 0.9980 - recall: 0.9977 - top_2_accuracy: 1.0000 - top_3_accuracy: 1.0000
# Epoch 19: val_categorical_accuracy did not improve from 0.87542
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 116s 199ms/step - categorical_accuracy: 0.9979 - f1_score: 0.9978 - loss: 0.4285 - precision: 0.9980 - recall: 0.9977 - top_2_accuracy: 1.0000 - top_3_accuracy: 1.0000 - val_categorical_accuracy: 0.8675 - val_f1_score: 0.8665 - val_loss: 1.1185 - val_precision: 0.8693 - val_recall: 0.8638 - val_top_2_accuracy: 0.9615 - val_top_3_accuracy: 0.9830 - learning_rate: 2.5000e-05
# Epoch 20/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - categorical_accuracy: 0.9984 - f1_score: 0.9984 - loss: 0.3894 - precision: 0.9986 - recall: 0.9983 - top_2_accuracy: 1.0000 - top_3_accuracy: 1.0000
# Epoch 20: val_categorical_accuracy did not improve from 0.87542
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 112s 192ms/step - categorical_accuracy: 0.9984 - f1_score: 0.9984 - loss: 0.3894 - precision: 0.9986 - recall: 0.9983 - top_2_accuracy: 1.0000 - top_3_accuracy: 1.0000 - val_categorical_accuracy: 0.8698 - val_f1_score: 0.8686 - val_loss: 1.1092 - val_precision: 0.8703 - val_recall: 0.8669 - val_top_2_accuracy: 0.9581 - val_top_3_accuracy: 0.9830 - learning_rate: 1.2500e-05
# Epoch 21/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - categorical_accuracy: 0.9988 - f1_score: 0.9988 - loss: 0.3639 - precision: 0.9988 - recall: 0.9987 - top_2_accuracy: 1.0000 - top_3_accuracy: 1.0000
# Epoch 21: val_categorical_accuracy did not improve from 0.87542
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 111s 190ms/step - categorical_accuracy: 0.9988 - f1_score: 0.9988 - loss: 0.3639 - precision: 0.9988 - recall: 0.9987 - top_2_accuracy: 1.0000 - top_3_accuracy: 1.0000 - val_categorical_accuracy: 0.8743 - val_f1_score: 0.8765 - val_loss: 1.0703 - val_precision: 0.8786 - val_recall: 0.8744 - val_top_2_accuracy: 0.9581 - val_top_3_accuracy: 0.9807 - learning_rate: 1.2500e-05
# Epoch 22/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - categorical_accuracy: 0.9985 - f1_score: 0.9984 - loss: 0.3520 - precision: 0.9985 - recall: 0.9984 - top_2_accuracy: 1.0000 - top_3_accuracy: 1.0000
# Epoch 22: val_categorical_accuracy improved from 0.87542 to 0.87769, saving model to best_model.keras
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 111s 190ms/step - categorical_accuracy: 0.9985 - f1_score: 0.9984 - loss: 0.3520 - precision: 0.9985 - recall: 0.9984 - top_2_accuracy: 1.0000 - top_3_accuracy: 1.0000 - val_categorical_accuracy: 0.8777 - val_f1_score: 0.8779 - val_loss: 1.0454 - val_precision: 0.8793 - val_recall: 0.8767 - val_top_2_accuracy: 0.9570 - val_top_3_accuracy: 0.9819 - learning_rate: 1.2500e-05
# Epoch 23/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - categorical_accuracy: 0.9989 - f1_score: 0.9989 - loss: 0.3260 - precision: 0.9990 - recall: 0.9988 - top_2_accuracy: 1.0000 - top_3_accuracy: 1.0000
# Epoch 23: val_categorical_accuracy did not improve from 0.87769
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 112s 192ms/step - categorical_accuracy: 0.9989 - f1_score: 0.9989 - loss: 0.3259 - precision: 0.9990 - recall: 0.9988 - top_2_accuracy: 1.0000 - top_3_accuracy: 1.0000 - val_categorical_accuracy: 0.8607 - val_f1_score: 0.8618 - val_loss: 1.0723 - val_precision: 0.8658 - val_recall: 0.8580 - val_top_2_accuracy: 0.9547 - val_top_3_accuracy: 0.9807 - learning_rate: 1.2500e-05
# Epoch 24/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - categorical_accuracy: 0.9987 - f1_score: 0.9987 - loss: 0.3089 - precision: 0.9988 - recall: 0.9987 - top_2_accuracy: 0.9999 - top_3_accuracy: 1.0000
# Epoch 24: val_categorical_accuracy did not improve from 0.87769
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 109s 186ms/step - categorical_accuracy: 0.9987 - f1_score: 0.9987 - loss: 0.3089 - precision: 0.9988 - recall: 0.9987 - top_2_accuracy: 0.9999 - top_3_accuracy: 1.0000 - val_categorical_accuracy: 0.8698 - val_f1_score: 0.8723 - val_loss: 1.0247 - val_precision: 0.8740 - val_recall: 0.8705 - val_top_2_accuracy: 0.9558 - val_top_3_accuracy: 0.9785 - learning_rate: 1.2500e-05
# Epoch 25/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - categorical_accuracy: 0.9991 - f1_score: 0.9990 - loss: 0.2859 - precision: 0.9991 - recall: 0.9989 - top_2_accuracy: 1.0000 - top_3_accuracy: 1.0000
# Epoch 25: val_categorical_accuracy did not improve from 0.87769
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1e-05.
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 113s 193ms/step - categorical_accuracy: 0.9991 - f1_score: 0.9990 - loss: 0.2859 - precision: 0.9991 - recall: 0.9989 - top_2_accuracy: 1.0000 - top_3_accuracy: 1.0000 - val_categorical_accuracy: 0.8664 - val_f1_score: 0.8659 - val_loss: 1.0053 - val_precision: 0.8680 - val_recall: 0.8638 - val_top_2_accuracy: 0.9502 - val_top_3_accuracy: 0.9807 - learning_rate: 1.2500e-05
# Epoch 26/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - categorical_accuracy: 0.9992 - f1_score: 0.9993 - loss: 0.2682 - precision: 0.9994 - recall: 0.9992 - top_2_accuracy: 0.9999 - top_3_accuracy: 1.0000
# Epoch 26: val_categorical_accuracy did not improve from 0.87769
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 111s 190ms/step - categorical_accuracy: 0.9992 - f1_score: 0.9993 - loss: 0.2682 - precision: 0.9994 - recall: 0.9992 - top_2_accuracy: 0.9999 - top_3_accuracy: 1.0000 - val_categorical_accuracy: 0.8754 - val_f1_score: 0.8758 - val_loss: 0.9681 - val_precision: 0.8772 - val_recall: 0.8744 - val_top_2_accuracy: 0.9479 - val_top_3_accuracy: 0.9785 - learning_rate: 1.0000e-05
# Epoch 27/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - categorical_accuracy: 0.9995 - f1_score: 0.9995 - loss: 0.2489 - precision: 0.9995 - recall: 0.9995 - top_2_accuracy: 1.0000 - top_3_accuracy: 1.0000
# Epoch 27: val_categorical_accuracy did not improve from 0.87769
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 110s 188ms/step - categorical_accuracy: 0.9995 - f1_score: 0.9995 - loss: 0.2489 - precision: 0.9995 - recall: 0.9995 - top_2_accuracy: 1.0000 - top_3_accuracy: 1.0000 - val_categorical_accuracy: 0.8766 - val_f1_score: 0.8801 - val_loss: 0.9537 - val_precision: 0.8828 - val_recall: 0.8775 - val_top_2_accuracy: 0.9536 - val_top_3_accuracy: 0.9796 - learning_rate: 1.0000e-05
# Epoch 28/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - categorical_accuracy: 0.9993 - f1_score: 0.9993 - loss: 0.2411 - precision: 0.9994 - recall: 0.9992 - top_2_accuracy: 1.0000 - top_3_accuracy: 1.0000
# Epoch 28: val_categorical_accuracy did not improve from 0.87769
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 110s 188ms/step - categorical_accuracy: 0.9993 - f1_score: 0.9993 - loss: 0.2411 - precision: 0.9994 - recall: 0.9992 - top_2_accuracy: 1.0000 - top_3_accuracy: 1.0000 - val_categorical_accuracy: 0.8754 - val_f1_score: 0.8758 - val_loss: 0.9714 - val_precision: 0.8773 - val_recall: 0.8744 - val_top_2_accuracy: 0.9502 - val_top_3_accuracy: 0.9785 - learning_rate: 1.0000e-05
# Epoch 29/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - categorical_accuracy: 0.9991 - f1_score: 0.9991 - loss: 0.2291 - precision: 0.9992 - recall: 0.9991 - top_2_accuracy: 1.0000 - top_3_accuracy: 1.0000
# Epoch 29: val_categorical_accuracy did not improve from 0.87769
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 108s 185ms/step - categorical_accuracy: 0.9991 - f1_score: 0.9991 - loss: 0.2291 - precision: 0.9992 - recall: 0.9991 - top_2_accuracy: 1.0000 - top_3_accuracy: 1.0000 - val_categorical_accuracy: 0.8743 - val_f1_score: 0.8772 - val_loss: 0.9873 - val_precision: 0.8786 - val_recall: 0.8758 - val_top_2_accuracy: 0.9502 - val_top_3_accuracy: 0.9807 - learning_rate: 1.0000e-05
# Epoch 30/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - categorical_accuracy: 0.9993 - f1_score: 0.9993 - loss: 0.2138 - precision: 0.9993 - recall: 0.9993 - top_2_accuracy: 1.0000 - top_3_accuracy: 1.0000
# Epoch 30: val_categorical_accuracy did not improve from 0.87769
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 107s 183ms/step - categorical_accuracy: 0.9993 - f1_score: 0.9993 - loss: 0.2137 - precision: 0.9993 - recall: 0.9993 - top_2_accuracy: 1.0000 - top_3_accuracy: 1.0000 - val_categorical_accuracy: 0.8777 - val_f1_score: 0.8781 - val_loss: 0.9442 - val_precision: 0.8796 - val_recall: 0.8767 - val_top_2_accuracy: 0.9536 - val_top_3_accuracy: 0.9762 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 30.

# %%
tl_model.save('val_loss_epoch.keras')

# %%
metrics = pd.DataFrame(tl_model.history.history)
metrics[["loss","val_loss"]].plot()
# Out:
# <Axes: >

# %%
metrics[["categorical_accuracy","val_categorical_accuracy"]].plot()
# Out:
# <Axes: >

# %%
# display the accuracy, top-2 accuracy and top-3 accuracy

import matplotlib.pyplot as plt

acc = history.history['categorical_accuracy']
val_acc = history.history['val_categorical_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
train_top2_acc = history.history['top_2_accuracy']
val_top2_acc = history.history['val_top_2_accuracy']
train_top3_acc = history.history['top_3_accuracy']
val_top3_acc = history.history['val_top_3_accuracy']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, loss, "-o", label='Training loss')
plt.plot(epochs, val_loss, "-o", label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
# plt.figure()
plt.savefig('loss.png', dpi=300)
plt.figure()

plt.plot(epochs, acc, "-o", label='Training cat acc')
plt.plot(epochs, val_acc, "-o", label='Validation cat acc')
plt.title('Training and validation cat accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
# plt.figure()
plt.savefig('acc.png', dpi=300)
plt.figure()

plt.plot(epochs, train_top2_acc, "-o", label='Training top2 acc')
plt.plot(epochs, val_top2_acc, "-o", label='Validation top2 acc')
plt.title('Training and validation top2 accuracy')
plt.xlabel('epochs')
plt.ylabel('top-2 accuracy')
plt.legend()
# plt.figure()
plt.savefig('top2acc.png', dpi=300)
plt.figure()

plt.plot(epochs, train_top3_acc, "-o", label='Training top3 acc')
plt.plot(epochs, val_top3_acc, "-o", label='Validation top3 acc')
plt.title('Training and validation top3 accuracy')
plt.xlabel('epochs')
plt.ylabel('top-3 accuracy')
plt.legend()
# plt.figure()
plt.savefig('top3acc.png', dpi=300)
plt.figure()

# %%
import numpy as np
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt

def plot_roc_curves_from_generator(predictions, test_labels, class_names):
    """
    Plot ROC curves for predictions from a generator-based model.
    
    Parameters:
    predictions: Raw predictions from model.predict()
    test_labels: True labels from generator.classes
    class_names: List of class names in order matching generator.class_indices
    """
    # Convert predictions to probabilities if not already
    if len(predictions.shape) == 1:  # If predictions are already argmaxed
        # Convert to one-hot
        n_classes = len(class_names)
        y_pred_proba = np.zeros((len(predictions), n_classes))
        for i, pred in enumerate(predictions):
            y_pred_proba[i, pred] = 1
    else:
        y_pred_proba = predictions
    
    # Binarize the labels
    y_test_bin = label_binarize(test_labels, classes=range(len(class_names)))
    
    # Create figure
    plt.figure(figsize=(12, 8))
    
    # Store AUC scores
    auc_scores = {}
    
    # Plot ROC curve for each class
    for i in range(len(class_names)):
        fpr, tpr, _ = roc_curve(y_test_bin[:, i], y_pred_proba[:, i])
        roc_auc = auc(fpr, tpr)
        auc_scores[class_names[i]] = roc_auc
        
        plt.plot(fpr, tpr, label=f'{class_names[i]} (AUC = {roc_auc:.2f})')
    
    # Add diagonal reference line
    plt.plot([0, 1], [0, 1], 'k--', label='Random')
    
    # Customize plot
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curves for Each Class')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.grid(True)
    
    return plt.gcf(), auc_scores

# %% [markdown]
# # Best Model Based on Validation Categorical Accuracy

# %%
tl_model.load_weights('best_model.keras')
VALIDATION_STEPS = int(np.ceil(count_jpg_files(validation_path) / 64))

# %%
val_loss, val_cat_acc, val_top_2_acc, val_top_3_acc, val_precision, val_recall, val_f1_score = tl_model.evaluate(val_image_gen, steps=VALIDATION_STEPS)

print('val_loss:', val_loss)
print('val_cat_acc:', val_cat_acc)
print('val_top_2_acc:', val_top_2_acc)
print('val_top_3_acc:', val_top_3_acc)
print('val_precision:', val_precision)
print('val_recall:', val_recall)
print('val_f1_score', val_f1_score)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 164ms/step - categorical_accuracy: 0.7624 - f1_score: 0.7618 - loss: 1.7863 - precision: 0.7648 - recall: 0.7588 - top_2_accuracy: 0.9070 - top_3_accuracy: 0.9623
# val_loss: 1.0454257726669312
# val_cat_acc: 0.8776897192001343
# val_top_2_acc: 0.956964910030365
# val_top_3_acc: 0.9818799495697021
# val_precision: 0.8792552947998047
# val_recall: 0.8766631484031677
# val_f1_score 0.8779386281967163

# %%
TEST_STEPS = int(np.ceil(count_jpg_files(test_path) / 64))

# %%
test_loss, test_cat_acc, test_top_2_acc, test_top_3_acc, test_precision, test_recall, test_f1_score = tl_model.evaluate(test_image_gen, steps=TEST_STEPS)

print('test_loss:', test_loss)
print('test_cat_acc:', test_cat_acc)
print('test_top_2_acc:', test_top_2_acc)
print('test_top_3_acc:', test_top_3_acc)
print('test_precision:', test_precision)
print('test_recall:', test_recall)
print('test_f1_score', test_f1_score)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 536ms/step - categorical_accuracy: 0.7459 - f1_score: 0.7475 - loss: 1.9843 - precision: 0.7532 - recall: 0.7421 - top_2_accuracy: 0.8757 - top_3_accuracy: 0.9368
# test_loss: 1.1098908185958862
# test_cat_acc: 0.8739800453186035
# test_top_2_acc: 0.9410697817802429
# test_top_3_acc: 0.9709882140159607
# test_precision: 0.8829765319824219
# test_recall: 0.8767361044883728
# test_f1_score 0.8798110485076904

# %%
predictions = tl_model.predict(test_image_gen, verbose=1)
class_names = list(test_image_gen.class_indices.keys())

fig, auc_scores = plot_roc_curves_from_generator(
    predictions,
    test_image_gen.classes,
    class_names
)

print("\nAUC Scores per class:")
for class_name, score in auc_scores.items():
    print(f'{class_name}: {score:.3f}')

plt.figure()
plt.savefig('roc_curves.png', bbox_inches='tight', dpi=300)
plt.close()
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 165ms/step
#
# AUC Scores per class:
# akiec: 0.939
# bcc: 0.986
# bkl: 0.925
# df: 0.962
# mel: 0.919
# nv: 0.968
# vasc: 1.000

# %%
predictions = tl_model.predict(test_image_gen, verbose=1)
predictions = predictions.argmax(axis=1)
test_labels = test_image_gen.classes
cm = confusion_matrix(test_labels, predictions)
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 164ms/step

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=True,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.figure(figsize=(7,7))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.savefig('confusionmatrix.png', dpi=300)

    
cm_plot_labels =['AKIEC','BCC','BKL','DF','MEL','NV','VASC']

plot_confusion_matrix(cm, cm_plot_labels, title='Confusion Matrix', normalize=True)
# Out:
# Normalized confusion matrix
# [[0.33333333 0.16666667 0.26666667 0.         0.06666667 0.16666667
#   0.        ]
#  [0.02857143 0.62857143 0.14285714 0.         0.05714286 0.14285714
#   0.        ]
#  [0.05681818 0.03409091 0.47727273 0.         0.19318182 0.23863636
#   0.        ]
#  [0.         0.         0.125      0.         0.125      0.75
#   0.        ]
#  [0.         0.02173913 0.08695652 0.         0.47826087 0.41304348
#   0.        ]
#  [0.         0.00566251 0.01472254 0.         0.01132503 0.96828992
#   0.        ]
#  [0.         0.         0.         0.         0.         0.
#   1.        ]]

# %%
df = pd.DataFrame(cm, index= ['AKIEC','BCC','BKL','DF','MEL','NV','VASC'], columns=['AKIEC','BCC','BKL','DF','MEL','NV','VASC'])
df.da.export_metrics()
# Out:
#                               AKIEC       BCC       BKL        DF       MEL  \
# accuracy                   0.976428  0.975521  0.930190  0.992747  0.949229
# f1                         0.434783  0.619718  0.521739       NaN  0.440000
# false_discovery_rate       0.375000  0.388889  0.424658       NaN  0.592593
# false_negative_rate        0.666667  0.371429  0.522727  1.000000  0.521739
# false_positive_rate        0.005592  0.013109  0.030542  0.000000  0.030274
# negative_predictive_value  0.981601  0.987816  0.955340  0.992747  0.977121
# positive_predictive_value  0.625000  0.611111  0.575342       NaN  0.407407
# precision                  0.625000  0.611111  0.575342       NaN  0.407407
# recall                     0.333333  0.628571  0.477273  0.000000  0.478261
# sensitivity                0.333333  0.628571  0.477273  0.000000  0.478261
# specificity                0.994408  0.986891  0.969458  1.000000  0.969726
# true_negative_rate         0.994408  0.986891  0.969458  1.000000  0.969726
# true_positive_rate         0.333333  0.628571  0.477273  0.000000  0.478261
#
#                                  NV  VASC  micro-average
# accuracy                   0.923844   1.0       0.963994
# f1                         0.953177   1.0       0.873980
# false_discovery_rate       0.061471   0.0       0.126020
# false_negative_rate        0.031710   0.0       0.126020
# false_positive_rate        0.254545   0.0       0.021003
# negative_predictive_value  0.854167   1.0       0.978997
# positive_predictive_value  0.938529   1.0       0.873980
# precision                  0.938529   1.0       0.873980
# recall                     0.968290   1.0       0.873980
# sensitivity                0.968290   1.0       0.873980
# specificity                0.745455   1.0       0.978997
# true_negative_rate         0.745455   1.0       0.978997
# true_positive_rate         0.968290   1.0       0.873980

# %% [markdown]
# # Best Model Based on Validation Loss

# %%
tl_model.load_weights('val_loss_epoch.keras')
VALIDATION_STEPS = int(np.ceil(count_jpg_files(validation_path) / 64))

# %%
val_loss, val_cat_acc, val_top_2_acc, val_top_3_acc, val_precision, val_recall, val_f1_score = tl_model.evaluate(val_image_gen, steps=VALIDATION_STEPS)

print('val_loss:', val_loss)
print('val_cat_acc:', val_cat_acc)
print('val_top_2_acc:', val_top_2_acc)
print('val_top_3_acc:', val_top_3_acc)
print('val_precision:', val_precision)
print('val_recall:', val_recall)
print('val_f1_score', val_f1_score)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 175ms/step - categorical_accuracy: 0.7646 - f1_score: 0.7638 - loss: 1.7008 - precision: 0.7673 - recall: 0.7604 - top_2_accuracy: 0.9003 - top_3_accuracy: 0.9456
# val_loss: 0.9442222714424133
# val_cat_acc: 0.8776897192001343
# val_top_2_acc: 0.953567385673523
# val_top_3_acc: 0.9762174487113953
# val_precision: 0.8796471953392029
# val_recall: 0.8766631484031677
# val_f1_score 0.878127932548523

# %%
TEST_STEPS = int(np.ceil(count_jpg_files(test_path) / 64))

# %%
test_loss, test_cat_acc, test_top_2_acc, test_top_3_acc, test_precision, test_recall, test_f1_score = tl_model.evaluate(test_image_gen, steps=TEST_STEPS)

print('test_loss:', test_loss)
print('test_cat_acc:', test_cat_acc)
print('test_top_2_acc:', test_top_2_acc)
print('test_top_3_acc:', test_top_3_acc)
print('test_precision:', test_precision)
print('test_recall:', test_recall)
print('test_f1_score', test_f1_score)
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 165ms/step - categorical_accuracy: 0.7459 - f1_score: 0.7470 - loss: 1.7774 - precision: 0.7497 - recall: 0.7444 - top_2_accuracy: 0.8647 - top_3_accuracy: 0.9374
# test_loss: 0.9588536620140076
# test_cat_acc: 0.8730734586715698
# test_top_2_acc: 0.9365367293357849
# test_top_3_acc: 0.9718948602676392
# test_precision: 0.881351113319397
# test_recall: 0.8776041865348816
# test_f1_score 0.87945955991745

# %%
predictions = tl_model.predict(test_image_gen, verbose=1)
class_names = list(test_image_gen.class_indices.keys())

fig, auc_scores = plot_roc_curves_from_generator(
    predictions,
    test_image_gen.classes,
    class_names
)

print("\nAUC Scores per class:")
for class_name, score in auc_scores.items():
    print(f'{class_name}: {score:.3f}')

plt.figure()
plt.savefig('roc_curves_valloss.png', bbox_inches='tight', dpi=300)
plt.close()
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 163ms/step
#
# AUC Scores per class:
# akiec: 0.942
# bcc: 0.984
# bkl: 0.923
# df: 0.963
# mel: 0.920
# nv: 0.966
# vasc: 1.000

# %%
predictions = tl_model.predict(test_image_gen, verbose=1)
predictions = predictions.argmax(axis=1)
test_labels = test_image_gen.classes
cm = confusion_matrix(test_labels, predictions)
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=True,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.figure(figsize=(7,7))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.savefig('confusionmatrix_valloss.png', dpi=300)

    
cm_plot_labels =['AKIEC','BCC','BKL','DF','MEL','NV','VASC']

plot_confusion_matrix(cm, cm_plot_labels, title='Confusion Matrix', normalize=True)
# Out:
# Normalized confusion matrix
# [[0.4        0.13333333 0.23333333 0.         0.06666667 0.16666667
#   0.        ]
#  [0.02857143 0.6        0.14285714 0.02857143 0.08571429 0.11428571
#   0.        ]
#  [0.05681818 0.05681818 0.47727273 0.01136364 0.14772727 0.25
#   0.        ]
#  [0.125      0.         0.125      0.125      0.         0.625
#   0.        ]
#  [0.         0.02173913 0.13043478 0.         0.43478261 0.41304348
#   0.        ]
#  [0.0011325  0.00679502 0.01698754 0.         0.00792752 0.96715742
#   0.        ]
#  [0.         0.         0.         0.         0.         0.
#   1.        ]]

# %%
df = pd.DataFrame(cm, index= ['AKIEC','BCC','BKL','DF','MEL','NV','VASC'], columns=['AKIEC','BCC','BKL','DF','MEL','NV','VASC'])
df.da.export_metrics()
# Out:
#                               AKIEC       BCC       BKL        DF       MEL  \
# accuracy                   0.976428  0.972801  0.927471  0.991840  0.953762
# f1                         0.480000  0.583333  0.512195  0.181818  0.439560
# false_discovery_rate       0.400000  0.432432  0.447368  0.666667  0.555556
# false_negative_rate        0.600000  0.400000  0.522727  0.875000  0.565217
# false_positive_rate        0.007456  0.014981  0.033498  0.001826  0.023652
# negative_predictive_value  0.983380  0.986867  0.955209  0.993636  0.975425
# positive_predictive_value  0.600000  0.567568  0.552632  0.333333  0.444444
# precision                  0.600000  0.567568  0.552632  0.333333  0.444444
# recall                     0.400000  0.600000  0.477273  0.125000  0.434783
# sensitivity                0.400000  0.600000  0.477273  0.125000  0.434783
# specificity                0.992544  0.985019  0.966502  0.998174  0.976348
# true_negative_rate         0.992544  0.985019  0.966502  0.998174  0.976348
# true_positive_rate         0.400000  0.600000  0.477273  0.125000  0.434783
#
#                                  NV  VASC  micro-average
# accuracy                   0.923844   1.0       0.963735
# f1                         0.953125   1.0       0.873073
# false_discovery_rate       0.060506   0.0       0.126927
# false_negative_rate        0.032843   0.0       0.126927
# false_positive_rate        0.250000   0.0       0.021154
# negative_predictive_value  0.850515   1.0       0.978846
# positive_predictive_value  0.939494   1.0       0.873073
# precision                  0.939494   1.0       0.873073
# recall                     0.967157   1.0       0.873073
# sensitivity                0.967157   1.0       0.873073
# specificity                0.750000   1.0       0.978846
# true_negative_rate         0.750000   1.0       0.978846
# true_positive_rate         0.967157   1.0       0.873073
