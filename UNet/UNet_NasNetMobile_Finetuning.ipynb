# %%
# !pip install disarray
# Out:
# Collecting disarray
#   Downloading disarray-0.2.0-py2.py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: pandas>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from disarray) (2.1.4)
# Requirement already satisfied: numpy>=0.14.2 in /usr/local/lib/python3.10/dist-packages (from disarray) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23.0->disarray) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23.0->disarray) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23.0->disarray) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=0.23.0->disarray) (1.16.0)
# Downloading disarray-0.2.0-py2.py3-none-any.whl (6.8 kB)
# Installing collected packages: disarray
# Successfully installed disarray-0.2.0

# %%
import tensorflow
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import os
import shutil
from tqdm import tqdm
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import cv2
import sklearn
from sklearn.metrics import classification_report, confusion_matrix
import itertools
import disarray

# %%
def count_jpg_files(root_dir):
    """
    Count all .jpg files in the given directory and its subdirectories
    
    Args:
        root_dir (str): Path to the root directory to start searching from
        
    Returns:
        int: total count
    """
    total_count = 0
    dir_counts = {}
    
    # Walk through all directories
    for dirpath, dirnames, filenames in os.walk(root_dir):
        # Count jpg files in current directory
        jpg_count = len([f for f in filenames if f.lower().endswith('.jpg')])
        total_count += jpg_count
    
    return total_count

# %%
train_path = '/kaggle/input/multiclassunetsegmentedimages/unet_segmented/train_directory'
validation_path = '/kaggle/input/multiclassunetsegmentedimages/unet_segmented/validation_directory'
test_path = '/kaggle/input/multiclassunetsegmentedimages/unet_segmented/test_directory'

# %%
preprocess_input = tensorflow.keras.applications.nasnet.preprocess_input

image_gen = ImageDataGenerator(preprocessing_function=preprocess_input)

# %%
batch_size = 64
train_image_gen = image_gen.flow_from_directory(train_path, 
                                          target_size=(224,224), 
                                          color_mode='rgb',
                                          batch_size=batch_size,
                                          class_mode='categorical')

val_image_gen = image_gen.flow_from_directory(validation_path, 
                                          target_size=(224,224), 
                                          color_mode='rgb',
                                          batch_size=batch_size,
                                          class_mode='categorical',
                                          shuffle=False)

test_image_gen = image_gen.flow_from_directory(test_path, 
                                          target_size=(224,224), 
                                          color_mode='rgb',
                                          batch_size=batch_size,
                                          class_mode='categorical',
                                          shuffle=False)

print(test_image_gen.class_indices)
# Out:
# Found 36927 images belonging to 7 classes.
# Found 883 images belonging to 7 classes.
# Found 1103 images belonging to 7 classes.
# {'akiec': 0, 'bcc': 1, 'bkl': 2, 'df': 3, 'mel': 4, 'nv': 5, 'vasc': 6}

# %%
from tensorflow.keras.applications import NASNetMobile
from tensorflow.keras.layers import Dense, Input, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

base_model = NASNetMobile(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

for layer in base_model.layers:
    layer.trainable = True

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(192,kernel_regularizer='l2',activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(7, activation='softmax')(x)
tl_model = Model(inputs=base_model.input, outputs=x)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-mobile-no-top.h5
# 19993432/19993432 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
tl_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 224, 224, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stem_conv1 (Conv2D)       │ (None, 111, 111, 32)   │            864 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stem_bn1                  │ (None, 111, 111, 32)   │            128 │ stem_conv1[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation (Activation)   │ (None, 111, 111, 32)   │              0 │ stem_bn1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reduction_conv_1_stem_1   │ (None, 111, 111, 11)   │            352 │ activation[0][0]       │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reduction_bn_1_stem_1     │ (None, 111, 111, 11)   │             44 │ reduction_conv_1_stem… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_1 (Activation) │ (None, 111, 111, 11)   │              0 │ reduction_bn_1_stem_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_3 (Activation) │ (None, 111, 111, 32)   │              0 │ stem_bn1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_pad_red… │ (None, 115, 115, 11)   │              0 │ activation_1[0][0]     │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_pad_red… │ (None, 117, 117, 32)   │              0 │ activation_3[0][0]     │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_reducti… │ (None, 56, 56, 11)     │            396 │ separable_conv_1_pad_… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_reducti… │ (None, 56, 56, 11)     │          1,920 │ separable_conv_1_pad_… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_bn_redu… │ (None, 56, 56, 11)     │             44 │ separable_conv_1_redu… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_bn_redu… │ (None, 56, 56, 11)     │             44 │ separable_conv_1_redu… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_2 (Activation) │ (None, 56, 56, 11)     │              0 │ separable_conv_1_bn_r… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_4 (Activation) │ (None, 56, 56, 11)     │              0 │ separable_conv_1_bn_r… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_reducti… │ (None, 56, 56, 11)     │            396 │ activation_2[0][0]     │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_reducti… │ (None, 56, 56, 11)     │            660 │ activation_4[0][0]     │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_5 (Activation) │ (None, 111, 111, 32)   │              0 │ stem_bn1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_bn_redu… │ (None, 56, 56, 11)     │             44 │ separable_conv_2_redu… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_bn_redu… │ (None, 56, 56, 11)     │             44 │ separable_conv_2_redu… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_pad_red… │ (None, 117, 117, 32)   │              0 │ activation_5[0][0]     │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_7 (Activation) │ (None, 111, 111, 32)   │              0 │ stem_bn1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reduction_add_1_stem_1    │ (None, 56, 56, 11)     │              0 │ separable_conv_2_bn_r… │
# │ (Add)                     │                        │                │ separable_conv_2_bn_r… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_reducti… │ (None, 56, 56, 11)     │          1,920 │ separable_conv_1_pad_… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_pad_red… │ (None, 115, 115, 32)   │              0 │ activation_7[0][0]     │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_9 (Activation) │ (None, 56, 56, 11)     │              0 │ reduction_add_1_stem_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_bn_redu… │ (None, 56, 56, 11)     │             44 │ separable_conv_1_redu… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_reducti… │ (None, 56, 56, 11)     │          1,152 │ separable_conv_1_pad_… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_reducti… │ (None, 56, 56, 11)     │            220 │ activation_9[0][0]     │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_6 (Activation) │ (None, 56, 56, 11)     │              0 │ separable_conv_1_bn_r… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_bn_redu… │ (None, 56, 56, 11)     │             44 │ separable_conv_1_redu… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_bn_redu… │ (None, 56, 56, 11)     │             44 │ separable_conv_1_redu… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reduction_pad_1_stem_1    │ (None, 113, 113, 11)   │              0 │ reduction_bn_1_stem_1… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_reducti… │ (None, 56, 56, 11)     │            660 │ activation_6[0][0]     │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_8 (Activation) │ (None, 56, 56, 11)     │              0 │ separable_conv_1_bn_r… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_10             │ (None, 56, 56, 11)     │              0 │ separable_conv_1_bn_r… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reduction_left2_stem_1    │ (None, 56, 56, 11)     │              0 │ reduction_pad_1_stem_… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_bn_redu… │ (None, 56, 56, 11)     │             44 │ separable_conv_2_redu… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_reducti… │ (None, 56, 56, 11)     │            396 │ activation_8[0][0]     │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_reducti… │ (None, 56, 56, 11)     │            220 │ activation_10[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ adjust_relu_1_stem_2      │ (None, 111, 111, 32)   │              0 │ stem_bn1[0][0]         │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reduction_add_2_stem_1    │ (None, 56, 56, 11)     │              0 │ reduction_left2_stem_… │
# │ (Add)                     │                        │                │ separable_conv_2_bn_r… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reduction_left3_stem_1    │ (None, 56, 56, 11)     │              0 │ reduction_pad_1_stem_… │
# │ (AveragePooling2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_bn_redu… │ (None, 56, 56, 11)     │             44 │ separable_conv_2_redu… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reduction_left4_stem_1    │ (None, 56, 56, 11)     │              0 │ reduction_add_1_stem_… │
# │ (AveragePooling2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_bn_redu… │ (None, 56, 56, 11)     │             44 │ separable_conv_2_redu… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reduction_right5_stem_1   │ (None, 56, 56, 11)     │              0 │ reduction_pad_1_stem_… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ zero_padding2d            │ (None, 112, 112, 32)   │              0 │ adjust_relu_1_stem_2[… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reduction_add3_stem_1     │ (None, 56, 56, 11)     │              0 │ reduction_left3_stem_… │
# │ (Add)                     │                        │                │ separable_conv_2_bn_r… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 56, 56, 11)     │              0 │ reduction_add_2_stem_… │
# │                           │                        │                │ reduction_left4_stem_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reduction_add4_stem_1     │ (None, 56, 56, 11)     │              0 │ separable_conv_2_bn_r… │
# │ (Add)                     │                        │                │ reduction_right5_stem… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ cropping2d (Cropping2D)   │ (None, 111, 111, 32)   │              0 │ zero_padding2d[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reduction_concat_stem_1   │ (None, 56, 56, 44)     │              0 │ reduction_add_2_stem_… │
# │ (Concatenate)             │                        │                │ reduction_add3_stem_1… │
# │                           │                        │                │ add[0][0],             │
# │                           │                        │                │ reduction_add4_stem_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ adjust_avg_pool_1_stem_2  │ (None, 56, 56, 32)     │              0 │ adjust_relu_1_stem_2[… │
# │ (AveragePooling2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ adjust_avg_pool_2_stem_2  │ (None, 56, 56, 32)     │              0 │ cropping2d[0][0]       │
# │ (AveragePooling2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_11             │ (None, 56, 56, 44)     │              0 │ reduction_concat_stem… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ adjust_conv_1_stem_2      │ (None, 56, 56, 11)     │            352 │ adjust_avg_pool_1_ste… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ adjust_conv_2_stem_2      │ (None, 56, 56, 11)     │            352 │ adjust_avg_pool_2_ste… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reduction_conv_1_stem_2   │ (None, 56, 56, 22)     │            968 │ activation_11[0][0]    │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 56, 56, 22)     │              0 │ adjust_conv_1_stem_2[… │
# │                           │                        │                │ adjust_conv_2_stem_2[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reduction_bn_1_stem_2     │ (None, 56, 56, 22)     │             88 │ reduction_conv_1_stem… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ adjust_bn_stem_2          │ (None, 56, 56, 22)     │             88 │ concatenate[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_12             │ (None, 56, 56, 22)     │              0 │ reduction_bn_1_stem_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_14             │ (None, 56, 56, 22)     │              0 │ adjust_bn_stem_2[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_pad_red… │ (None, 59, 59, 22)     │              0 │ activation_12[0][0]    │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_pad_red… │ (None, 61, 61, 22)     │              0 │ activation_14[0][0]    │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_reducti… │ (None, 28, 28, 22)     │          1,034 │ separable_conv_1_pad_… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_reducti… │ (None, 28, 28, 22)     │          1,562 │ separable_conv_1_pad_… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_bn_redu… │ (None, 28, 28, 22)     │             88 │ separable_conv_1_redu… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_bn_redu… │ (None, 28, 28, 22)     │             88 │ separable_conv_1_redu… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_13             │ (None, 28, 28, 22)     │              0 │ separable_conv_1_bn_r… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_15             │ (None, 28, 28, 22)     │              0 │ separable_conv_1_bn_r… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_reducti… │ (None, 28, 28, 22)     │          1,034 │ activation_13[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_reducti… │ (None, 28, 28, 22)     │          1,562 │ activation_15[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_16             │ (None, 56, 56, 22)     │              0 │ adjust_bn_stem_2[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_bn_redu… │ (None, 28, 28, 22)     │             88 │ separable_conv_2_redu… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_bn_redu… │ (None, 28, 28, 22)     │             88 │ separable_conv_2_redu… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_pad_red… │ (None, 61, 61, 22)     │              0 │ activation_16[0][0]    │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_18             │ (None, 56, 56, 22)     │              0 │ adjust_bn_stem_2[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reduction_add_1_stem_2    │ (None, 28, 28, 22)     │              0 │ separable_conv_2_bn_r… │
# │ (Add)                     │                        │                │ separable_conv_2_bn_r… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_reducti… │ (None, 28, 28, 22)     │          1,562 │ separable_conv_1_pad_… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_pad_red… │ (None, 59, 59, 22)     │              0 │ activation_18[0][0]    │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_20             │ (None, 28, 28, 22)     │              0 │ reduction_add_1_stem_… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_bn_redu… │ (None, 28, 28, 22)     │             88 │ separable_conv_1_redu… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_reducti… │ (None, 28, 28, 22)     │          1,034 │ separable_conv_1_pad_… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_reducti… │ (None, 28, 28, 22)     │            682 │ activation_20[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_17             │ (None, 28, 28, 22)     │              0 │ separable_conv_1_bn_r… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_bn_redu… │ (None, 28, 28, 22)     │             88 │ separable_conv_1_redu… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_bn_redu… │ (None, 28, 28, 22)     │             88 │ separable_conv_1_redu… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reduction_pad_1_stem_2    │ (None, 57, 57, 22)     │              0 │ reduction_bn_1_stem_2… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_reducti… │ (None, 28, 28, 22)     │          1,562 │ activation_17[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_19             │ (None, 28, 28, 22)     │              0 │ separable_conv_1_bn_r… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_21             │ (None, 28, 28, 22)     │              0 │ separable_conv_1_bn_r… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reduction_left2_stem_2    │ (None, 28, 28, 22)     │              0 │ reduction_pad_1_stem_… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_bn_redu… │ (None, 28, 28, 22)     │             88 │ separable_conv_2_redu… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_reducti… │ (None, 28, 28, 22)     │          1,034 │ activation_19[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_reducti… │ (None, 28, 28, 22)     │            682 │ activation_21[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ adjust_relu_1_0           │ (None, 56, 56, 44)     │              0 │ reduction_concat_stem… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reduction_add_2_stem_2    │ (None, 28, 28, 22)     │              0 │ reduction_left2_stem_… │
# │ (Add)                     │                        │                │ separable_conv_2_bn_r… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reduction_left3_stem_2    │ (None, 28, 28, 22)     │              0 │ reduction_pad_1_stem_… │
# │ (AveragePooling2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_bn_redu… │ (None, 28, 28, 22)     │             88 │ separable_conv_2_redu… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reduction_left4_stem_2    │ (None, 28, 28, 22)     │              0 │ reduction_add_1_stem_… │
# │ (AveragePooling2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_bn_redu… │ (None, 28, 28, 22)     │             88 │ separable_conv_2_redu… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reduction_right5_stem_2   │ (None, 28, 28, 22)     │              0 │ reduction_pad_1_stem_… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ zero_padding2d_1          │ (None, 57, 57, 44)     │              0 │ adjust_relu_1_0[0][0]  │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reduction_add3_stem_2     │ (None, 28, 28, 22)     │              0 │ reduction_left3_stem_… │
# │ (Add)                     │                        │                │ separable_conv_2_bn_r… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_1 (Add)               │ (None, 28, 28, 22)     │              0 │ reduction_add_2_stem_… │
# │                           │                        │                │ reduction_left4_stem_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reduction_add4_stem_2     │ (None, 28, 28, 22)     │              0 │ separable_conv_2_bn_r… │
# │ (Add)                     │                        │                │ reduction_right5_stem… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ cropping2d_1 (Cropping2D) │ (None, 56, 56, 44)     │              0 │ zero_padding2d_1[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reduction_concat_stem_2   │ (None, 28, 28, 88)     │              0 │ reduction_add_2_stem_… │
# │ (Concatenate)             │                        │                │ reduction_add3_stem_2… │
# │                           │                        │                │ add_1[0][0],           │
# │                           │                        │                │ reduction_add4_stem_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ adjust_avg_pool_1_0       │ (None, 28, 28, 44)     │              0 │ adjust_relu_1_0[0][0]  │
# │ (AveragePooling2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ adjust_avg_pool_2_0       │ (None, 28, 28, 44)     │              0 │ cropping2d_1[0][0]     │
# │ (AveragePooling2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ adjust_conv_1_0 (Conv2D)  │ (None, 28, 28, 22)     │            968 │ adjust_avg_pool_1_0[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ adjust_conv_2_0 (Conv2D)  │ (None, 28, 28, 22)     │            968 │ adjust_avg_pool_2_0[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_22             │ (None, 28, 28, 88)     │              0 │ reduction_concat_stem… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 28, 28, 44)     │              0 │ adjust_conv_1_0[0][0], │
# │ (Concatenate)             │                        │                │ adjust_conv_2_0[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normal_conv_1_0 (Conv2D)  │ (None, 28, 28, 44)     │          3,872 │ activation_22[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ adjust_bn_0               │ (None, 28, 28, 44)     │            176 │ concatenate_1[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normal_bn_1_0             │ (None, 28, 28, 44)     │            176 │ normal_conv_1_0[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_23             │ (None, 28, 28, 44)     │              0 │ normal_bn_1_0[0][0]    │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_25             │ (None, 28, 28, 44)     │              0 │ adjust_bn_0[0][0]      │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_27             │ (None, 28, 28, 44)     │              0 │ adjust_bn_0[0][0]      │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_29             │ (None, 28, 28, 44)     │              0 │ adjust_bn_0[0][0]      │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_31             │ (None, 28, 28, 44)     │              0 │ normal_bn_1_0[0][0]    │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_normal_… │ (None, 28, 28, 44)     │          3,036 │ activation_23[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_normal_… │ (None, 28, 28, 44)     │          2,332 │ activation_25[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_normal_… │ (None, 28, 28, 44)     │          3,036 │ activation_27[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_normal_… │ (None, 28, 28, 44)     │          2,332 │ activation_29[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_normal_… │ (None, 28, 28, 44)     │          2,332 │ activation_31[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_bn_norm… │ (None, 28, 28, 44)     │            176 │ separable_conv_1_norm… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_bn_norm… │ (None, 28, 28, 44)     │            176 │ separable_conv_1_norm… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_bn_norm… │ (None, 28, 28, 44)     │            176 │ separable_conv_1_norm… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_bn_norm… │ (None, 28, 28, 44)     │            176 │ separable_conv_1_norm… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_bn_norm… │ (None, 28, 28, 44)     │            176 │ separable_conv_1_norm… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_24             │ (None, 28, 28, 44)     │              0 │ separable_conv_1_bn_n… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_26             │ (None, 28, 28, 44)     │              0 │ separable_conv_1_bn_n… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_28             │ (None, 28, 28, 44)     │              0 │ separable_conv_1_bn_n… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_30             │ (None, 28, 28, 44)     │              0 │ separable_conv_1_bn_n… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_32             │ (None, 28, 28, 44)     │              0 │ separable_conv_1_bn_n… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_normal_… │ (None, 28, 28, 44)     │          3,036 │ activation_24[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_normal_… │ (None, 28, 28, 44)     │          2,332 │ activation_26[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_normal_… │ (None, 28, 28, 44)     │          3,036 │ activation_28[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_normal_… │ (None, 28, 28, 44)     │          2,332 │ activation_30[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_normal_… │ (None, 28, 28, 44)     │          2,332 │ activation_32[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_bn_norm… │ (None, 28, 28, 44)     │            176 │ separable_conv_2_norm… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_bn_norm… │ (None, 28, 28, 44)     │            176 │ separable_conv_2_norm… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_bn_norm… │ (None, 28, 28, 44)     │            176 │ separable_conv_2_norm… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_bn_norm… │ (None, 28, 28, 44)     │            176 │ separable_conv_2_norm… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normal_left3_0            │ (None, 28, 28, 44)     │              0 │ normal_bn_1_0[0][0]    │
# │ (AveragePooling2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normal_left4_0            │ (None, 28, 28, 44)     │              0 │ adjust_bn_0[0][0]      │
# │ (AveragePooling2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normal_right4_0           │ (None, 28, 28, 44)     │              0 │ adjust_bn_0[0][0]      │
# │ (AveragePooling2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_bn_norm… │ (None, 28, 28, 44)     │            176 │ separable_conv_2_norm… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normal_add_1_0 (Add)      │ (None, 28, 28, 44)     │              0 │ separable_conv_2_bn_n… │
# │                           │                        │                │ separable_conv_2_bn_n… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normal_add_2_0 (Add)      │ (None, 28, 28, 44)     │              0 │ separable_conv_2_bn_n… │
# │                           │                        │                │ separable_conv_2_bn_n… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normal_add_3_0 (Add)      │ (None, 28, 28, 44)     │              0 │ normal_left3_0[0][0],  │
# │                           │                        │                │ adjust_bn_0[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normal_add_4_0 (Add)      │ (None, 28, 28, 44)     │              0 │ normal_left4_0[0][0],  │
# │                           │                        │                │ normal_right4_0[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normal_add_5_0 (Add)      │ (None, 28, 28, 44)     │              0 │ separable_conv_2_bn_n… │
# │                           │                        │                │ normal_bn_1_0[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normal_concat_0           │ (None, 28, 28, 264)    │              0 │ adjust_bn_0[0][0],     │
# │ (Concatenate)             │                        │                │ normal_add_1_0[0][0],  │
# │                           │                        │                │ normal_add_2_0[0][0],  │
# │                           │                        │                │ normal_add_3_0[0][0],  │
# │                           │                        │                │ normal_add_4_0[0][0],  │
# │                           │                        │                │ normal_add_5_0[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_33             │ (None, 28, 28, 88)     │              0 │ reduction_concat_stem… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_34             │ (None, 28, 28, 264)    │              0 │ normal_concat_0[0][0]  │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ adjust_conv_projection_1  │ (None, 28, 28, 44)     │          3,872 │ activation_33[0][0]    │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normal_conv_1_1 (Conv2D)  │ (None, 28, 28, 44)     │         11,616 │ activation_34[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ adjust_bn_1               │ (None, 28, 28, 44)     │            176 │ adjust_conv_projectio… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normal_bn_1_1             │ (None, 28, 28, 44)     │            176 │ normal_conv_1_1[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_35             │ (None, 28, 28, 44)     │              0 │ normal_bn_1_1[0][0]    │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_37             │ (None, 28, 28, 44)     │              0 │ adjust_bn_1[0][0]      │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# ...
# │ normal_add_4_11 (Add)     │ (None, 7, 7, 176)      │              0 │ normal_left4_11[0][0], │
# │                           │                        │                │ normal_right4_11[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normal_add_5_11 (Add)     │ (None, 7, 7, 176)      │              0 │ separable_conv_2_bn_n… │
# │                           │                        │                │ normal_bn_1_11[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normal_concat_11          │ (None, 7, 7, 1056)     │              0 │ adjust_bn_11[0][0],    │
# │ (Concatenate)             │                        │                │ normal_add_1_11[0][0], │
# │                           │                        │                │ normal_add_2_11[0][0], │
# │                           │                        │                │ normal_add_3_11[0][0], │
# │                           │                        │                │ normal_add_4_11[0][0], │
# │                           │                        │                │ normal_add_5_11[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_175            │ (None, 7, 7, 1056)     │              0 │ normal_concat_10[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_176            │ (None, 7, 7, 1056)     │              0 │ normal_concat_11[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ adjust_conv_projection_12 │ (None, 7, 7, 176)      │        185,856 │ activation_175[0][0]   │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normal_conv_1_12 (Conv2D) │ (None, 7, 7, 176)      │        185,856 │ activation_176[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ adjust_bn_12              │ (None, 7, 7, 176)      │            704 │ adjust_conv_projectio… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normal_bn_1_12            │ (None, 7, 7, 176)      │            704 │ normal_conv_1_12[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_177            │ (None, 7, 7, 176)      │              0 │ normal_bn_1_12[0][0]   │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_179            │ (None, 7, 7, 176)      │              0 │ adjust_bn_12[0][0]     │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_181            │ (None, 7, 7, 176)      │              0 │ adjust_bn_12[0][0]     │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_183            │ (None, 7, 7, 176)      │              0 │ adjust_bn_12[0][0]     │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_185            │ (None, 7, 7, 176)      │              0 │ normal_bn_1_12[0][0]   │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_normal_… │ (None, 7, 7, 176)      │         35,376 │ activation_177[0][0]   │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_normal_… │ (None, 7, 7, 176)      │         32,560 │ activation_179[0][0]   │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_normal_… │ (None, 7, 7, 176)      │         35,376 │ activation_181[0][0]   │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_normal_… │ (None, 7, 7, 176)      │         32,560 │ activation_183[0][0]   │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_normal_… │ (None, 7, 7, 176)      │         32,560 │ activation_185[0][0]   │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_bn_norm… │ (None, 7, 7, 176)      │            704 │ separable_conv_1_norm… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_bn_norm… │ (None, 7, 7, 176)      │            704 │ separable_conv_1_norm… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_bn_norm… │ (None, 7, 7, 176)      │            704 │ separable_conv_1_norm… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_bn_norm… │ (None, 7, 7, 176)      │            704 │ separable_conv_1_norm… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_1_bn_norm… │ (None, 7, 7, 176)      │            704 │ separable_conv_1_norm… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_178            │ (None, 7, 7, 176)      │              0 │ separable_conv_1_bn_n… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_180            │ (None, 7, 7, 176)      │              0 │ separable_conv_1_bn_n… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_182            │ (None, 7, 7, 176)      │              0 │ separable_conv_1_bn_n… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_184            │ (None, 7, 7, 176)      │              0 │ separable_conv_1_bn_n… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_186            │ (None, 7, 7, 176)      │              0 │ separable_conv_1_bn_n… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_normal_… │ (None, 7, 7, 176)      │         35,376 │ activation_178[0][0]   │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_normal_… │ (None, 7, 7, 176)      │         32,560 │ activation_180[0][0]   │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_normal_… │ (None, 7, 7, 176)      │         35,376 │ activation_182[0][0]   │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_normal_… │ (None, 7, 7, 176)      │         32,560 │ activation_184[0][0]   │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_normal_… │ (None, 7, 7, 176)      │         32,560 │ activation_186[0][0]   │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_bn_norm… │ (None, 7, 7, 176)      │            704 │ separable_conv_2_norm… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_bn_norm… │ (None, 7, 7, 176)      │            704 │ separable_conv_2_norm… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_bn_norm… │ (None, 7, 7, 176)      │            704 │ separable_conv_2_norm… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_bn_norm… │ (None, 7, 7, 176)      │            704 │ separable_conv_2_norm… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normal_left3_12           │ (None, 7, 7, 176)      │              0 │ normal_bn_1_12[0][0]   │
# │ (AveragePooling2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normal_left4_12           │ (None, 7, 7, 176)      │              0 │ adjust_bn_12[0][0]     │
# │ (AveragePooling2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normal_right4_12          │ (None, 7, 7, 176)      │              0 │ adjust_bn_12[0][0]     │
# │ (AveragePooling2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv_2_bn_norm… │ (None, 7, 7, 176)      │            704 │ separable_conv_2_norm… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normal_add_1_12 (Add)     │ (None, 7, 7, 176)      │              0 │ separable_conv_2_bn_n… │
# │                           │                        │                │ separable_conv_2_bn_n… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normal_add_2_12 (Add)     │ (None, 7, 7, 176)      │              0 │ separable_conv_2_bn_n… │
# │                           │                        │                │ separable_conv_2_bn_n… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normal_add_3_12 (Add)     │ (None, 7, 7, 176)      │              0 │ normal_left3_12[0][0], │
# │                           │                        │                │ adjust_bn_12[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normal_add_4_12 (Add)     │ (None, 7, 7, 176)      │              0 │ normal_left4_12[0][0], │
# │                           │                        │                │ normal_right4_12[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normal_add_5_12 (Add)     │ (None, 7, 7, 176)      │              0 │ separable_conv_2_bn_n… │
# │                           │                        │                │ normal_bn_1_12[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normal_concat_12          │ (None, 7, 7, 1056)     │              0 │ adjust_bn_12[0][0],    │
# │ (Concatenate)             │                        │                │ normal_add_1_12[0][0], │
# │                           │                        │                │ normal_add_2_12[0][0], │
# │                           │                        │                │ normal_add_3_12[0][0], │
# │                           │                        │                │ normal_add_4_12[0][0], │
# │                           │                        │                │ normal_add_5_12[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_187            │ (None, 7, 7, 1056)     │              0 │ normal_concat_12[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (None, 1056)           │              0 │ activation_187[0][0]   │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 192)            │        202,944 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 192)            │              0 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 7)              │          1,351 │ dropout[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 4,474,011 (17.07 MB)
#  Trainable params: 4,437,273 (16.93 MB)
#  Non-trainable params: 36,738 (143.51 KB)

# %%
from tensorflow.keras import backend as K
from tensorflow.keras.metrics import categorical_accuracy, top_k_categorical_accuracy

def top_3_accuracy(y_true, y_pred):
    return top_k_categorical_accuracy(y_true, y_pred, k=3)

def top_2_accuracy(y_true, y_pred):
    return top_k_categorical_accuracy(y_true, y_pred, k=2)

def precision(y_true, y_pred):
    """Precision metric.
    Only computes a batch-wise average of precision.
    Computes the precision, a metric for multi-label classification of
    how many selected items are relevant.
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision_value = true_positives / (predicted_positives + K.epsilon())
    return precision_value

def recall(y_true, y_pred):
    """Recall metric.
    Only computes a batch-wise average of recall.
    Computes the recall, a metric for multi-label classification of
    how many relevant items are selected.
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall_value = true_positives / (possible_positives + K.epsilon())
    return recall_value

def f1_score(y_true, y_pred):
    precision_value = precision(y_true, y_pred)
    recall_value = recall(y_true, y_pred)
    f1_score_value = 2*((precision_value*recall_value)/(precision_value+recall_value+K.epsilon()))
    return f1_score_value

# %%
optimizer = Adam(0.0001)
tl_model.compile(loss="categorical_crossentropy", optimizer=optimizer, metrics=[categorical_accuracy, top_2_accuracy, top_3_accuracy, precision, recall, f1_score])

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint

lr_reduce = ReduceLROnPlateau(
    monitor='val_categorical_accuracy',
    factor=0.5,
    patience=3,        
    mode='max',
    min_lr=0.00001,
    verbose=1
)

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=10,       
    mode='min',
    restore_best_weights=True,
    verbose=1
)

model_chkpt = ModelCheckpoint(
    "best_model.keras",
    save_best_only=True,
    monitor='val_categorical_accuracy',
    mode='max',
    verbose=1
)

callback_list = [model_chkpt, lr_reduce, early_stop]

# %%
total_samples = sum([5115, 5950, 5990, 5462, 5510, 4810, 4090])
class_weights = {
    0: total_samples / 5510,
    1: total_samples / 5462,
    2: total_samples / 5990,
    3: total_samples / 4090,
    4: total_samples / 5950,
    5: total_samples / 5115,
    6: total_samples / 4810
}

# %%
history = tl_model.fit(train_image_gen,
                       epochs=30, 
                       validation_data = val_image_gen,
                       class_weight=class_weights,
                       callbacks=callback_list)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - categorical_accuracy: 0.4665 - f1_score: 0.3497 - loss: 12.7145 - precision: 0.6211 - recall: 0.2663 - top_2_accuracy: 0.6569 - top_3_accuracy: 0.7879
# Epoch 1: val_categorical_accuracy improved from -inf to 0.29558, saving model to best_model.keras
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 495s 548ms/step - categorical_accuracy: 0.4667 - f1_score: 0.3500 - loss: 12.7105 - precision: 0.6212 - recall: 0.2665 - top_2_accuracy: 0.6571 - top_3_accuracy: 0.7880 - val_categorical_accuracy: 0.2956 - val_f1_score: 0.2205 - val_loss: 5.2838 - val_precision: 0.2565 - val_recall: 0.1940 - val_top_2_accuracy: 0.6716 - val_top_3_accuracy: 0.8335 - learning_rate: 1.0000e-04
# Epoch 2/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - categorical_accuracy: 0.7626 - f1_score: 0.7509 - loss: 7.0105 - precision: 0.8205 - recall: 0.6933 - top_2_accuracy: 0.9130 - top_3_accuracy: 0.9705
# Epoch 2: val_categorical_accuracy improved from 0.29558 to 0.76557, saving model to best_model.keras
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 215s 371ms/step - categorical_accuracy: 0.7626 - f1_score: 0.7510 - loss: 7.0100 - precision: 0.8205 - recall: 0.6934 - top_2_accuracy: 0.9130 - top_3_accuracy: 0.9706 - val_categorical_accuracy: 0.7656 - val_f1_score: 0.7460 - val_loss: 3.2311 - val_precision: 0.7912 - val_recall: 0.7123 - val_top_2_accuracy: 0.8754 - val_top_3_accuracy: 0.9366 - learning_rate: 1.0000e-04
# Epoch 3/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - categorical_accuracy: 0.8479 - f1_score: 0.8455 - loss: 5.1350 - precision: 0.8800 - recall: 0.8140 - top_2_accuracy: 0.9560 - top_3_accuracy: 0.9885
# Epoch 3: val_categorical_accuracy improved from 0.76557 to 0.82786, saving model to best_model.keras
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 215s 371ms/step - categorical_accuracy: 0.8479 - f1_score: 0.8455 - loss: 5.1348 - precision: 0.8801 - recall: 0.8141 - top_2_accuracy: 0.9560 - top_3_accuracy: 0.9885 - val_categorical_accuracy: 0.8279 - val_f1_score: 0.8276 - val_loss: 2.7246 - val_precision: 0.8570 - val_recall: 0.8024 - val_top_2_accuracy: 0.9026 - val_top_3_accuracy: 0.9400 - learning_rate: 1.0000e-04
# Epoch 4/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - categorical_accuracy: 0.9041 - f1_score: 0.9039 - loss: 3.8256 - precision: 0.9200 - recall: 0.8887 - top_2_accuracy: 0.9775 - top_3_accuracy: 0.9944
# Epoch 4: val_categorical_accuracy did not improve from 0.82786
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 213s 367ms/step - categorical_accuracy: 0.9041 - f1_score: 0.9039 - loss: 3.8254 - precision: 0.9200 - recall: 0.8887 - top_2_accuracy: 0.9775 - top_3_accuracy: 0.9944 - val_categorical_accuracy: 0.8086 - val_f1_score: 0.8085 - val_loss: 2.5013 - val_precision: 0.8318 - val_recall: 0.7884 - val_top_2_accuracy: 0.9015 - val_top_3_accuracy: 0.9524 - learning_rate: 1.0000e-04
# Epoch 5/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - categorical_accuracy: 0.9390 - f1_score: 0.9394 - loss: 2.9244 - precision: 0.9475 - recall: 0.9315 - top_2_accuracy: 0.9879 - top_3_accuracy: 0.9974
# Epoch 5: val_categorical_accuracy improved from 0.82786 to 0.84824, saving model to best_model.keras
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 215s 371ms/step - categorical_accuracy: 0.9389 - f1_score: 0.9394 - loss: 2.9244 - precision: 0.9475 - recall: 0.9315 - top_2_accuracy: 0.9879 - top_3_accuracy: 0.9974 - val_categorical_accuracy: 0.8482 - val_f1_score: 0.8486 - val_loss: 2.1256 - val_precision: 0.8586 - val_recall: 0.8392 - val_top_2_accuracy: 0.9230 - val_top_3_accuracy: 0.9728 - learning_rate: 1.0000e-04
# Epoch 6/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - categorical_accuracy: 0.9587 - f1_score: 0.9595 - loss: 2.2892 - precision: 0.9644 - recall: 0.9547 - top_2_accuracy: 0.9943 - top_3_accuracy: 0.9991
# Epoch 6: val_categorical_accuracy improved from 0.84824 to 0.85617, saving model to best_model.keras
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 215s 371ms/step - categorical_accuracy: 0.9587 - f1_score: 0.9595 - loss: 2.2891 - precision: 0.9644 - recall: 0.9547 - top_2_accuracy: 0.9943 - top_3_accuracy: 0.9991 - val_categorical_accuracy: 0.8562 - val_f1_score: 0.8519 - val_loss: 1.8178 - val_precision: 0.8677 - val_recall: 0.8373 - val_top_2_accuracy: 0.9479 - val_top_3_accuracy: 0.9751 - learning_rate: 1.0000e-04
# Epoch 7/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - categorical_accuracy: 0.9701 - f1_score: 0.9708 - loss: 1.8342 - precision: 0.9736 - recall: 0.9680 - top_2_accuracy: 0.9973 - top_3_accuracy: 0.9996
# Epoch 7: val_categorical_accuracy did not improve from 0.85617
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 214s 369ms/step - categorical_accuracy: 0.9701 - f1_score: 0.9708 - loss: 1.8342 - precision: 0.9736 - recall: 0.9680 - top_2_accuracy: 0.9973 - top_3_accuracy: 0.9996 - val_categorical_accuracy: 0.8550 - val_f1_score: 0.8581 - val_loss: 1.6890 - val_precision: 0.8674 - val_recall: 0.8499 - val_top_2_accuracy: 0.9468 - val_top_3_accuracy: 0.9740 - learning_rate: 1.0000e-04
# Epoch 8/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - categorical_accuracy: 0.9781 - f1_score: 0.9783 - loss: 1.5030 - precision: 0.9798 - recall: 0.9769 - top_2_accuracy: 0.9974 - top_3_accuracy: 0.9998
# Epoch 8: val_categorical_accuracy improved from 0.85617 to 0.85957, saving model to best_model.keras
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 215s 370ms/step - categorical_accuracy: 0.9781 - f1_score: 0.9783 - loss: 1.5031 - precision: 0.9798 - recall: 0.9769 - top_2_accuracy: 0.9974 - top_3_accuracy: 0.9998 - val_categorical_accuracy: 0.8596 - val_f1_score: 0.8564 - val_loss: 1.5619 - val_precision: 0.8612 - val_recall: 0.8521 - val_top_2_accuracy: 0.9388 - val_top_3_accuracy: 0.9694 - learning_rate: 1.0000e-04
# Epoch 9/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - categorical_accuracy: 0.9802 - f1_score: 0.9801 - loss: 1.2695 - precision: 0.9818 - recall: 0.9784 - top_2_accuracy: 0.9984 - top_3_accuracy: 0.9997
# Epoch 9: val_categorical_accuracy did not improve from 0.85957
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 213s 367ms/step - categorical_accuracy: 0.9802 - f1_score: 0.9801 - loss: 1.2694 - precision: 0.9818 - recall: 0.9784 - top_2_accuracy: 0.9984 - top_3_accuracy: 0.9997 - val_categorical_accuracy: 0.8573 - val_f1_score: 0.8554 - val_loss: 1.5076 - val_precision: 0.8577 - val_recall: 0.8532 - val_top_2_accuracy: 0.9320 - val_top_3_accuracy: 0.9615 - learning_rate: 1.0000e-04
# Epoch 10/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - categorical_accuracy: 0.9826 - f1_score: 0.9827 - loss: 1.0577 - precision: 0.9839 - recall: 0.9815 - top_2_accuracy: 0.9985 - top_3_accuracy: 0.9999
# Epoch 10: val_categorical_accuracy did not improve from 0.85957
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 213s 367ms/step - categorical_accuracy: 0.9826 - f1_score: 0.9827 - loss: 1.0577 - precision: 0.9839 - recall: 0.9815 - top_2_accuracy: 0.9985 - top_3_accuracy: 0.9999 - val_categorical_accuracy: 0.8584 - val_f1_score: 0.8611 - val_loss: 1.2842 - val_precision: 0.8648 - val_recall: 0.8577 - val_top_2_accuracy: 0.9400 - val_top_3_accuracy: 0.9706 - learning_rate: 1.0000e-04
# Epoch 11/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - categorical_accuracy: 0.9866 - f1_score: 0.9866 - loss: 0.8449 - precision: 0.9876 - recall: 0.9856 - top_2_accuracy: 0.9987 - top_3_accuracy: 0.9999
# Epoch 11: val_categorical_accuracy improved from 0.85957 to 0.86976, saving model to best_model.keras
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 216s 372ms/step - categorical_accuracy: 0.9866 - f1_score: 0.9866 - loss: 0.8448 - precision: 0.9876 - recall: 0.9856 - top_2_accuracy: 0.9987 - top_3_accuracy: 0.9999 - val_categorical_accuracy: 0.8698 - val_f1_score: 0.8664 - val_loss: 1.1129 - val_precision: 0.8717 - val_recall: 0.8613 - val_top_2_accuracy: 0.9513 - val_top_3_accuracy: 0.9751 - learning_rate: 1.0000e-04
# Epoch 12/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - categorical_accuracy: 0.9862 - f1_score: 0.9862 - loss: 0.7404 - precision: 0.9869 - recall: 0.9855 - top_2_accuracy: 0.9988 - top_3_accuracy: 0.9998
# Epoch 12: val_categorical_accuracy did not improve from 0.86976
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 214s 369ms/step - categorical_accuracy: 0.9862 - f1_score: 0.9862 - loss: 0.7404 - precision: 0.9869 - recall: 0.9855 - top_2_accuracy: 0.9988 - top_3_accuracy: 0.9998 - val_categorical_accuracy: 0.8675 - val_f1_score: 0.8665 - val_loss: 1.0468 - val_precision: 0.8708 - val_recall: 0.8624 - val_top_2_accuracy: 0.9445 - val_top_3_accuracy: 0.9740 - learning_rate: 1.0000e-04
# Epoch 13/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - categorical_accuracy: 0.9885 - f1_score: 0.9880 - loss: 0.6133 - precision: 0.9891 - recall: 0.9870 - top_2_accuracy: 0.9993 - top_3_accuracy: 1.0000
# Epoch 13: val_categorical_accuracy did not improve from 0.86976
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 214s 369ms/step - categorical_accuracy: 0.9885 - f1_score: 0.9880 - loss: 0.6133 - precision: 0.9891 - recall: 0.9870 - top_2_accuracy: 0.9993 - top_3_accuracy: 1.0000 - val_categorical_accuracy: 0.8460 - val_f1_score: 0.8470 - val_loss: 1.0294 - val_precision: 0.8507 - val_recall: 0.8437 - val_top_2_accuracy: 0.9366 - val_top_3_accuracy: 0.9638 - learning_rate: 1.0000e-04
# Epoch 14/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - categorical_accuracy: 0.9885 - f1_score: 0.9886 - loss: 0.5284 - precision: 0.9891 - recall: 0.9881 - top_2_accuracy: 0.9990 - top_3_accuracy: 1.0000
# Epoch 14: val_categorical_accuracy did not improve from 0.86976
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 213s 367ms/step - categorical_accuracy: 0.9885 - f1_score: 0.9886 - loss: 0.5285 - precision: 0.9891 - recall: 0.9881 - top_2_accuracy: 0.9990 - top_3_accuracy: 1.0000 - val_categorical_accuracy: 0.8664 - val_f1_score: 0.8648 - val_loss: 1.2077 - val_precision: 0.8666 - val_recall: 0.8630 - val_top_2_accuracy: 0.9320 - val_top_3_accuracy: 0.9604 - learning_rate: 1.0000e-04
# Epoch 15/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - categorical_accuracy: 0.9942 - f1_score: 0.9943 - loss: 0.3819 - precision: 0.9945 - recall: 0.9941 - top_2_accuracy: 0.9993 - top_3_accuracy: 1.0000
# Epoch 15: val_categorical_accuracy improved from 0.86976 to 0.87656, saving model to best_model.keras
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 215s 370ms/step - categorical_accuracy: 0.9942 - f1_score: 0.9943 - loss: 0.3819 - precision: 0.9945 - recall: 0.9941 - top_2_accuracy: 0.9993 - top_3_accuracy: 1.0000 - val_categorical_accuracy: 0.8766 - val_f1_score: 0.8741 - val_loss: 1.0397 - val_precision: 0.8768 - val_recall: 0.8716 - val_top_2_accuracy: 0.9490 - val_top_3_accuracy: 0.9785 - learning_rate: 5.0000e-05
# Epoch 16/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - categorical_accuracy: 0.9975 - f1_score: 0.9975 - loss: 0.2790 - precision: 0.9977 - recall: 0.9974 - top_2_accuracy: 0.9999 - top_3_accuracy: 1.0000
# Epoch 16: val_categorical_accuracy did not improve from 0.87656
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 214s 368ms/step - categorical_accuracy: 0.9975 - f1_score: 0.9975 - loss: 0.2790 - precision: 0.9977 - recall: 0.9974 - top_2_accuracy: 0.9999 - top_3_accuracy: 1.0000 - val_categorical_accuracy: 0.8720 - val_f1_score: 0.8724 - val_loss: 1.0044 - val_precision: 0.8735 - val_recall: 0.8713 - val_top_2_accuracy: 0.9366 - val_top_3_accuracy: 0.9694 - learning_rate: 5.0000e-05
# Epoch 17/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - categorical_accuracy: 0.9963 - f1_score: 0.9964 - loss: 0.2604 - precision: 0.9965 - recall: 0.9962 - top_2_accuracy: 0.9998 - top_3_accuracy: 1.0000
# Epoch 17: val_categorical_accuracy did not improve from 0.87656
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 214s 369ms/step - categorical_accuracy: 0.9963 - f1_score: 0.9964 - loss: 0.2604 - precision: 0.9965 - recall: 0.9962 - top_2_accuracy: 0.9998 - top_3_accuracy: 1.0000 - val_categorical_accuracy: 0.8754 - val_f1_score: 0.8765 - val_loss: 0.8216 - val_precision: 0.8781 - val_recall: 0.8750 - val_top_2_accuracy: 0.9558 - val_top_3_accuracy: 0.9819 - learning_rate: 5.0000e-05
# Epoch 18/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - categorical_accuracy: 0.9965 - f1_score: 0.9966 - loss: 0.2289 - precision: 0.9967 - recall: 0.9964 - top_2_accuracy: 0.9999 - top_3_accuracy: 1.0000
# Epoch 18: val_categorical_accuracy improved from 0.87656 to 0.87769, saving model to best_model.keras
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 216s 372ms/step - categorical_accuracy: 0.9965 - f1_score: 0.9966 - loss: 0.2289 - precision: 0.9967 - recall: 0.9964 - top_2_accuracy: 0.9999 - top_3_accuracy: 1.0000 - val_categorical_accuracy: 0.8777 - val_f1_score: 0.8767 - val_loss: 0.7993 - val_precision: 0.8791 - val_recall: 0.8744 - val_top_2_accuracy: 0.9536 - val_top_3_accuracy: 0.9819 - learning_rate: 5.0000e-05
# Epoch 19/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - categorical_accuracy: 0.9967 - f1_score: 0.9967 - loss: 0.2080 - precision: 0.9968 - recall: 0.9966 - top_2_accuracy: 0.9999 - top_3_accuracy: 1.0000
# Epoch 19: val_categorical_accuracy did not improve from 0.87769
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 214s 369ms/step - categorical_accuracy: 0.9967 - f1_score: 0.9967 - loss: 0.2080 - precision: 0.9968 - recall: 0.9966 - top_2_accuracy: 0.9999 - top_3_accuracy: 1.0000 - val_categorical_accuracy: 0.8720 - val_f1_score: 0.8689 - val_loss: 0.7950 - val_precision: 0.8724 - val_recall: 0.8655 - val_top_2_accuracy: 0.9536 - val_top_3_accuracy: 0.9819 - learning_rate: 5.0000e-05
# Epoch 20/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - categorical_accuracy: 0.9977 - f1_score: 0.9977 - loss: 0.1745 - precision: 0.9979 - recall: 0.9976 - top_2_accuracy: 0.9999 - top_3_accuracy: 1.0000
# Epoch 20: val_categorical_accuracy did not improve from 0.87769
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 214s 370ms/step - categorical_accuracy: 0.9977 - f1_score: 0.9977 - loss: 0.1745 - precision: 0.9979 - recall: 0.9976 - top_2_accuracy: 0.9999 - top_3_accuracy: 1.0000 - val_categorical_accuracy: 0.8664 - val_f1_score: 0.8678 - val_loss: 0.7999 - val_precision: 0.8687 - val_recall: 0.8669 - val_top_2_accuracy: 0.9513 - val_top_3_accuracy: 0.9762 - learning_rate: 5.0000e-05
# Epoch 21/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - categorical_accuracy: 0.9973 - f1_score: 0.9974 - loss: 0.1636 - precision: 0.9975 - recall: 0.9973 - top_2_accuracy: 0.9998 - top_3_accuracy: 0.9999
# Epoch 21: val_categorical_accuracy improved from 0.87769 to 0.87995, saving model to best_model.keras
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 216s 372ms/step - categorical_accuracy: 0.9973 - f1_score: 0.9974 - loss: 0.1636 - precision: 0.9975 - recall: 0.9973 - top_2_accuracy: 0.9998 - top_3_accuracy: 0.9999 - val_categorical_accuracy: 0.8800 - val_f1_score: 0.8805 - val_loss: 0.7725 - val_precision: 0.8819 - val_recall: 0.8792 - val_top_2_accuracy: 0.9570 - val_top_3_accuracy: 0.9864 - learning_rate: 5.0000e-05
# Epoch 22/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - categorical_accuracy: 0.9962 - f1_score: 0.9962 - loss: 0.1830 - precision: 0.9964 - recall: 0.9961 - top_2_accuracy: 0.9996 - top_3_accuracy: 1.0000
# Epoch 22: val_categorical_accuracy improved from 0.87995 to 0.88335, saving model to best_model.keras
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 217s 374ms/step - categorical_accuracy: 0.9962 - f1_score: 0.9962 - loss: 0.1830 - precision: 0.9964 - recall: 0.9961 - top_2_accuracy: 0.9996 - top_3_accuracy: 1.0000 - val_categorical_accuracy: 0.8834 - val_f1_score: 0.8854 - val_loss: 0.7312 - val_precision: 0.8872 - val_recall: 0.8836 - val_top_2_accuracy: 0.9660 - val_top_3_accuracy: 0.9807 - learning_rate: 5.0000e-05
# Epoch 23/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - categorical_accuracy: 0.9968 - f1_score: 0.9967 - loss: 0.1551 - precision: 0.9969 - recall: 0.9965 - top_2_accuracy: 0.9997 - top_3_accuracy: 1.0000
# Epoch 23: val_categorical_accuracy did not improve from 0.88335
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 214s 369ms/step - categorical_accuracy: 0.9968 - f1_score: 0.9967 - loss: 0.1552 - precision: 0.9969 - recall: 0.9965 - top_2_accuracy: 0.9997 - top_3_accuracy: 1.0000 - val_categorical_accuracy: 0.8686 - val_f1_score: 0.8679 - val_loss: 0.8348 - val_precision: 0.8686 - val_recall: 0.8672 - val_top_2_accuracy: 0.9536 - val_top_3_accuracy: 0.9807 - learning_rate: 5.0000e-05
# Epoch 24/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - categorical_accuracy: 0.9956 - f1_score: 0.9957 - loss: 0.1576 - precision: 0.9958 - recall: 0.9955 - top_2_accuracy: 0.9997 - top_3_accuracy: 1.0000
# Epoch 24: val_categorical_accuracy did not improve from 0.88335
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 214s 368ms/step - categorical_accuracy: 0.9956 - f1_score: 0.9957 - loss: 0.1576 - precision: 0.9958 - recall: 0.9955 - top_2_accuracy: 0.9997 - top_3_accuracy: 1.0000 - val_categorical_accuracy: 0.8698 - val_f1_score: 0.8688 - val_loss: 0.8005 - val_precision: 0.8699 - val_recall: 0.8677 - val_top_2_accuracy: 0.9547 - val_top_3_accuracy: 0.9830 - learning_rate: 5.0000e-05
# Epoch 25/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - categorical_accuracy: 0.9977 - f1_score: 0.9977 - loss: 0.1142 - precision: 0.9978 - recall: 0.9976 - top_2_accuracy: 1.0000 - top_3_accuracy: 1.0000
# Epoch 25: val_categorical_accuracy did not improve from 0.88335
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 214s 368ms/step - categorical_accuracy: 0.9977 - f1_score: 0.9977 - loss: 0.1142 - precision: 0.9978 - recall: 0.9976 - top_2_accuracy: 1.0000 - top_3_accuracy: 1.0000 - val_categorical_accuracy: 0.8675 - val_f1_score: 0.8680 - val_loss: 0.8013 - val_precision: 0.8688 - val_recall: 0.8672 - val_top_2_accuracy: 0.9581 - val_top_3_accuracy: 0.9819 - learning_rate: 5.0000e-05
# Epoch 26/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - categorical_accuracy: 0.9978 - f1_score: 0.9978 - loss: 0.1082 - precision: 0.9979 - recall: 0.9977 - top_2_accuracy: 0.9999 - top_3_accuracy: 1.0000
# Epoch 26: val_categorical_accuracy did not improve from 0.88335
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 214s 368ms/step - categorical_accuracy: 0.9978 - f1_score: 0.9978 - loss: 0.1082 - precision: 0.9979 - recall: 0.9977 - top_2_accuracy: 0.9999 - top_3_accuracy: 1.0000 - val_categorical_accuracy: 0.8596 - val_f1_score: 0.8599 - val_loss: 0.8765 - val_precision: 0.8599 - val_recall: 0.8599 - val_top_2_accuracy: 0.9570 - val_top_3_accuracy: 0.9785 - learning_rate: 2.5000e-05
# Epoch 27/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - categorical_accuracy: 0.9993 - f1_score: 0.9993 - loss: 0.0793 - precision: 0.9993 - recall: 0.9993 - top_2_accuracy: 1.0000 - top_3_accuracy: 1.0000
# Epoch 27: val_categorical_accuracy did not improve from 0.88335
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 213s 368ms/step - categorical_accuracy: 0.9993 - f1_score: 0.9993 - loss: 0.0793 - precision: 0.9993 - recall: 0.9993 - top_2_accuracy: 1.0000 - top_3_accuracy: 1.0000 - val_categorical_accuracy: 0.8822 - val_f1_score: 0.8838 - val_loss: 0.7741 - val_precision: 0.8860 - val_recall: 0.8817 - val_top_2_accuracy: 0.9570 - val_top_3_accuracy: 0.9887 - learning_rate: 2.5000e-05
# Epoch 28/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - categorical_accuracy: 0.9994 - f1_score: 0.9994 - loss: 0.0707 - precision: 0.9994 - recall: 0.9994 - top_2_accuracy: 1.0000 - top_3_accuracy: 1.0000
# Epoch 28: val_categorical_accuracy did not improve from 0.88335
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 213s 368ms/step - categorical_accuracy: 0.9994 - f1_score: 0.9994 - loss: 0.0707 - precision: 0.9994 - recall: 0.9994 - top_2_accuracy: 1.0000 - top_3_accuracy: 1.0000 - val_categorical_accuracy: 0.8743 - val_f1_score: 0.8743 - val_loss: 0.8013 - val_precision: 0.8760 - val_recall: 0.8727 - val_top_2_accuracy: 0.9592 - val_top_3_accuracy: 0.9841 - learning_rate: 2.5000e-05
# Epoch 29/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - categorical_accuracy: 0.9997 - f1_score: 0.9997 - loss: 0.0609 - precision: 0.9997 - recall: 0.9997 - top_2_accuracy: 1.0000 - top_3_accuracy: 1.0000
# Epoch 29: val_categorical_accuracy did not improve from 0.88335
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 213s 368ms/step - categorical_accuracy: 0.9997 - f1_score: 0.9997 - loss: 0.0609 - precision: 0.9997 - recall: 0.9997 - top_2_accuracy: 1.0000 - top_3_accuracy: 1.0000 - val_categorical_accuracy: 0.8788 - val_f1_score: 0.8801 - val_loss: 0.7898 - val_precision: 0.8807 - val_recall: 0.8794 - val_top_2_accuracy: 0.9581 - val_top_3_accuracy: 0.9887 - learning_rate: 1.2500e-05
# Epoch 30/30
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - categorical_accuracy: 0.9996 - f1_score: 0.9996 - loss: 0.0564 - precision: 0.9996 - recall: 0.9996 - top_2_accuracy: 1.0000 - top_3_accuracy: 1.0000
# Epoch 30: val_categorical_accuracy did not improve from 0.88335
# 577/577 ━━━━━━━━━━━━━━━━━━━━ 213s 367ms/step - categorical_accuracy: 0.9996 - f1_score: 0.9996 - loss: 0.0564 - precision: 0.9996 - recall: 0.9996 - top_2_accuracy: 1.0000 - top_3_accuracy: 1.0000 - val_categorical_accuracy: 0.8834 - val_f1_score: 0.8848 - val_loss: 0.7436 - val_precision: 0.8869 - val_recall: 0.8828 - val_top_2_accuracy: 0.9581 - val_top_3_accuracy: 0.9853 - learning_rate: 1.2500e-05
# Restoring model weights from the end of the best epoch: 22.

# %%
tl_model.save('val_loss_epoch.keras')

# %%
metrics = pd.DataFrame(tl_model.history.history)
metrics[["loss","val_loss"]].plot()
# Out:
# <Axes: >

# %%
metrics[["categorical_accuracy","val_categorical_accuracy"]].plot()
# Out:
# <Axes: >

# %%
# display the accuracy, top-2 accuracy and top-3 accuracy

import matplotlib.pyplot as plt

acc = history.history['categorical_accuracy']
val_acc = history.history['val_categorical_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
train_top2_acc = history.history['top_2_accuracy']
val_top2_acc = history.history['val_top_2_accuracy']
train_top3_acc = history.history['top_3_accuracy']
val_top3_acc = history.history['val_top_3_accuracy']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, loss, "-o", label='Training loss')
plt.plot(epochs, val_loss, "-o", label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
# plt.figure()
plt.savefig('loss.png', dpi=300)
plt.figure()

plt.plot(epochs, acc, "-o", label='Training cat acc')
plt.plot(epochs, val_acc, "-o", label='Validation cat acc')
plt.title('Training and validation cat accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
# plt.figure()
plt.savefig('acc.png', dpi=300)
plt.figure()

plt.plot(epochs, train_top2_acc, "-o", label='Training top2 acc')
plt.plot(epochs, val_top2_acc, "-o", label='Validation top2 acc')
plt.title('Training and validation top2 accuracy')
plt.xlabel('epochs')
plt.ylabel('top-2 accuracy')
plt.legend()
# plt.figure()
plt.savefig('top2acc.png', dpi=300)
plt.figure()

plt.plot(epochs, train_top3_acc, "-o", label='Training top3 acc')
plt.plot(epochs, val_top3_acc, "-o", label='Validation top3 acc')
plt.title('Training and validation top3 accuracy')
plt.xlabel('epochs')
plt.ylabel('top-3 accuracy')
plt.legend()
# plt.figure()
plt.savefig('top3acc.png', dpi=300)
plt.figure()

# %%
import numpy as np
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt

def plot_roc_curves_from_generator(predictions, test_labels, class_names):
    """
    Plot ROC curves for predictions from a generator-based model.
    
    Parameters:
    predictions: Raw predictions from model.predict()
    test_labels: True labels from generator.classes
    class_names: List of class names in order matching generator.class_indices
    """
    # Convert predictions to probabilities if not already
    if len(predictions.shape) == 1:  # If predictions are already argmaxed
        # Convert to one-hot
        n_classes = len(class_names)
        y_pred_proba = np.zeros((len(predictions), n_classes))
        for i, pred in enumerate(predictions):
            y_pred_proba[i, pred] = 1
    else:
        y_pred_proba = predictions
    
    # Binarize the labels
    y_test_bin = label_binarize(test_labels, classes=range(len(class_names)))
    
    # Create figure
    plt.figure(figsize=(12, 8))
    
    # Store AUC scores
    auc_scores = {}
    
    # Plot ROC curve for each class
    for i in range(len(class_names)):
        fpr, tpr, _ = roc_curve(y_test_bin[:, i], y_pred_proba[:, i])
        roc_auc = auc(fpr, tpr)
        auc_scores[class_names[i]] = roc_auc
        
        plt.plot(fpr, tpr, label=f'{class_names[i]} (AUC = {roc_auc:.2f})')
    
    # Add diagonal reference line
    plt.plot([0, 1], [0, 1], 'k--', label='Random')
    
    # Customize plot
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curves for Each Class')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.grid(True)
    
    return plt.gcf(), auc_scores

# %% [markdown]
# # Best Model Based on Validation Categorical Accuracy

# %%
tl_model.load_weights('best_model.keras')
VALIDATION_STEPS = int(np.ceil(count_jpg_files(validation_path) / 64))

# %%
val_loss, val_cat_acc, val_top_2_acc, val_top_3_acc, val_precision, val_recall, val_f1_score = tl_model.evaluate(val_image_gen, steps=VALIDATION_STEPS)

print('val_loss:', val_loss)
print('val_cat_acc:', val_cat_acc)
print('val_top_2_acc:', val_top_2_acc)
print('val_top_3_acc:', val_top_3_acc)
print('val_precision:', val_precision)
print('val_recall:', val_recall)
print('val_f1_score', val_f1_score)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 156ms/step - categorical_accuracy: 0.7657 - f1_score: 0.7675 - loss: 1.4130 - precision: 0.7693 - recall: 0.7658 - top_2_accuracy: 0.9210 - top_3_accuracy: 0.9545
# val_loss: 0.7311730980873108
# val_cat_acc: 0.8833522200584412
# val_top_2_acc: 0.9660249352455139
# val_top_3_acc: 0.9807474613189697
# val_precision: 0.8871783018112183
# val_recall: 0.8836221694946289
# val_f1_score 0.8853848576545715

# %%
TEST_STEPS = int(np.ceil(count_jpg_files(test_path) / 64))

# %%
test_loss, test_cat_acc, test_top_2_acc, test_top_3_acc, test_precision, test_recall, test_f1_score = tl_model.evaluate(test_image_gen, steps=TEST_STEPS)

print('test_loss:', test_loss)
print('test_cat_acc:', test_cat_acc)
print('test_top_2_acc:', test_top_2_acc)
print('test_top_3_acc:', test_top_3_acc)
print('test_precision:', test_precision)
print('test_recall:', test_recall)
print('test_f1_score', test_f1_score)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 13s 779ms/step - categorical_accuracy: 0.7664 - f1_score: 0.7659 - loss: 1.4449 - precision: 0.7681 - recall: 0.7637 - top_2_accuracy: 0.8804 - top_3_accuracy: 0.9352
# test_loss: 0.7168867588043213
# test_cat_acc: 0.8848595023155212
# test_top_2_acc: 0.9474161267280579
# test_top_3_acc: 0.9755213260650635
# test_precision: 0.8890014290809631
# test_recall: 0.8860532641410828
# test_f1_score 0.8875123262405396

# %%
predictions = tl_model.predict(test_image_gen, verbose=1)
class_names = list(test_image_gen.class_indices.keys())

fig, auc_scores = plot_roc_curves_from_generator(
    predictions,
    test_image_gen.classes,
    class_names
)

print("\nAUC Scores per class:")
for class_name, score in auc_scores.items():
    print(f'{class_name}: {score:.3f}')

plt.figure()
plt.savefig('roc_curves.png', bbox_inches='tight', dpi=300)
plt.close()
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 26s 796ms/step
#
# AUC Scores per class:
# akiec: 0.911
# bcc: 0.971
# bkl: 0.927
# df: 0.924
# mel: 0.948
# nv: 0.972
# vasc: 1.000

# %%
predictions = tl_model.predict(test_image_gen, verbose=1)
predictions = predictions.argmax(axis=1)
test_labels = test_image_gen.classes
cm = confusion_matrix(test_labels, predictions)
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=True,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.figure(figsize=(7,7))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.savefig('confusionmatrix.png', dpi=300)

    
cm_plot_labels =['AKIEC','BCC','BKL','DF','MEL','NV','VASC']

plot_confusion_matrix(cm, cm_plot_labels, title='Confusion Matrix', normalize=True)
# Out:
# Normalized confusion matrix
# [[0.46666667 0.03333333 0.2        0.         0.16666667 0.13333333
#   0.        ]
#  [0.14285714 0.51428571 0.11428571 0.02857143 0.05714286 0.14285714
#   0.        ]
#  [0.01136364 0.02272727 0.5        0.01136364 0.21590909 0.23863636
#   0.        ]
#  [0.         0.         0.125      0.5        0.         0.375
#   0.        ]
#  [0.         0.         0.15217391 0.         0.63043478 0.2173913
#   0.        ]
#  [0.0011325  0.00226501 0.01245753 0.0011325  0.01585504 0.96715742
#   0.        ]
#  [0.         0.         0.         0.         0.         0.
#   1.        ]]

# %%
df = pd.DataFrame(cm, index= ['AKIEC','BCC','BKL','DF','MEL','NV','VASC'], columns=['AKIEC','BCC','BKL','DF','MEL','NV','VASC'])
df.da.export_metrics()
# Out:
#                               AKIEC       BCC       BKL        DF       MEL  \
# accuracy                   0.979148  0.980054  0.933817  0.993654  0.948323
# f1                         0.549020  0.620690  0.546584  0.533333  0.504348
# false_discovery_rate       0.333333  0.217391  0.397260  0.428571  0.579710
# false_negative_rate        0.533333  0.485714  0.500000  0.500000  0.369565
# false_positive_rate        0.006524  0.004682  0.028571  0.002740  0.037843
# negative_predictive_value  0.985213  0.984259  0.957282  0.996350  0.983559
# positive_predictive_value  0.666667  0.782609  0.602740  0.571429  0.420290
# precision                  0.666667  0.782609  0.602740  0.571429  0.420290
# recall                     0.466667  0.514286  0.500000  0.500000  0.630435
# sensitivity                0.466667  0.514286  0.500000  0.500000  0.630435
# specificity                0.993476  0.995318  0.971429  0.997260  0.962157
# true_negative_rate         0.993476  0.995318  0.971429  0.997260  0.962157
# true_positive_rate         0.466667  0.514286  0.500000  0.500000  0.630435
#
#                                  NV  VASC  micro-average
# accuracy                   0.934723   1.0       0.967103
# f1                         0.959551   1.0       0.884859
# false_discovery_rate       0.047938   0.0       0.115141
# false_negative_rate        0.032843   0.0       0.115141
# false_positive_rate        0.195455   0.0       0.019190
# negative_predictive_value  0.859223   1.0       0.980810
# positive_predictive_value  0.952062   1.0       0.884859
# precision                  0.952062   1.0       0.884859
# recall                     0.967157   1.0       0.884859
# sensitivity                0.967157   1.0       0.884859
# specificity                0.804545   1.0       0.980810
# true_negative_rate         0.804545   1.0       0.980810
# true_positive_rate         0.967157   1.0       0.884859

# %% [markdown]
# # Best Model Based on Validation Loss

# %%
tl_model.load_weights('val_loss_epoch.keras')
VALIDATION_STEPS = int(np.ceil(count_jpg_files(validation_path) / 64))

# %%
val_loss, val_cat_acc, val_top_2_acc, val_top_3_acc, val_precision, val_recall, val_f1_score = tl_model.evaluate(val_image_gen, steps=VALIDATION_STEPS)

print('val_loss:', val_loss)
print('val_cat_acc:', val_cat_acc)
print('val_top_2_acc:', val_top_2_acc)
print('val_top_3_acc:', val_top_3_acc)
print('val_precision:', val_precision)
print('val_recall:', val_recall)
print('val_f1_score', val_f1_score)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 143ms/step - categorical_accuracy: 0.7657 - f1_score: 0.7675 - loss: 1.4130 - precision: 0.7693 - recall: 0.7658 - top_2_accuracy: 0.9210 - top_3_accuracy: 0.9545
# val_loss: 0.7311730980873108
# val_cat_acc: 0.8833522200584412
# val_top_2_acc: 0.9660249352455139
# val_top_3_acc: 0.9807474613189697
# val_precision: 0.8871783018112183
# val_recall: 0.8836221694946289
# val_f1_score 0.8853848576545715

# %%
TEST_STEPS = int(np.ceil(count_jpg_files(test_path) / 64))

# %%
test_loss, test_cat_acc, test_top_2_acc, test_top_3_acc, test_precision, test_recall, test_f1_score = tl_model.evaluate(test_image_gen, steps=TEST_STEPS)

print('test_loss:', test_loss)
print('test_cat_acc:', test_cat_acc)
print('test_top_2_acc:', test_top_2_acc)
print('test_top_3_acc:', test_top_3_acc)
print('test_precision:', test_precision)
print('test_recall:', test_recall)
print('test_f1_score', test_f1_score)
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - categorical_accuracy: 0.7664 - f1_score: 0.7659 - loss: 1.4449 - precision: 0.7681 - recall: 0.7637 - top_2_accuracy: 0.8804 - top_3_accuracy: 0.9352
# test_loss: 0.7168867588043213
# test_cat_acc: 0.8848595023155212
# test_top_2_acc: 0.9474161267280579
# test_top_3_acc: 0.9755213260650635
# test_precision: 0.8890014290809631
# test_recall: 0.8860532641410828
# test_f1_score 0.8875123262405396

# %%
predictions = tl_model.predict(test_image_gen, verbose=1)
class_names = list(test_image_gen.class_indices.keys())

fig, auc_scores = plot_roc_curves_from_generator(
    predictions,
    test_image_gen.classes,
    class_names
)

print("\nAUC Scores per class:")
for class_name, score in auc_scores.items():
    print(f'{class_name}: {score:.3f}')

plt.figure()
plt.savefig('roc_curves_valloss.png', bbox_inches='tight', dpi=300)
plt.close()
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step
#
# AUC Scores per class:
# akiec: 0.911
# bcc: 0.971
# bkl: 0.927
# df: 0.924
# mel: 0.948
# nv: 0.972
# vasc: 1.000

# %%
predictions = tl_model.predict(test_image_gen, verbose=1)
predictions = predictions.argmax(axis=1)
test_labels = test_image_gen.classes
cm = confusion_matrix(test_labels, predictions)
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=True,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.figure(figsize=(7,7))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.savefig('confusionmatrix_valloss.png', dpi=300)

    
cm_plot_labels =['AKIEC','BCC','BKL','DF','MEL','NV','VASC']

plot_confusion_matrix(cm, cm_plot_labels, title='Confusion Matrix', normalize=True)
# Out:
# Normalized confusion matrix
# [[0.46666667 0.03333333 0.2        0.         0.16666667 0.13333333
#   0.        ]
#  [0.14285714 0.51428571 0.11428571 0.02857143 0.05714286 0.14285714
#   0.        ]
#  [0.01136364 0.02272727 0.5        0.01136364 0.21590909 0.23863636
#   0.        ]
#  [0.         0.         0.125      0.5        0.         0.375
#   0.        ]
#  [0.         0.         0.15217391 0.         0.63043478 0.2173913
#   0.        ]
#  [0.0011325  0.00226501 0.01245753 0.0011325  0.01585504 0.96715742
#   0.        ]
#  [0.         0.         0.         0.         0.         0.
#   1.        ]]

# %%
df = pd.DataFrame(cm, index= ['AKIEC','BCC','BKL','DF','MEL','NV','VASC'], columns=['AKIEC','BCC','BKL','DF','MEL','NV','VASC'])
df.da.export_metrics()
# Out:
#                               AKIEC       BCC       BKL        DF       MEL  \
# accuracy                   0.979148  0.980054  0.933817  0.993654  0.948323
# f1                         0.549020  0.620690  0.546584  0.533333  0.504348
# false_discovery_rate       0.333333  0.217391  0.397260  0.428571  0.579710
# false_negative_rate        0.533333  0.485714  0.500000  0.500000  0.369565
# false_positive_rate        0.006524  0.004682  0.028571  0.002740  0.037843
# negative_predictive_value  0.985213  0.984259  0.957282  0.996350  0.983559
# positive_predictive_value  0.666667  0.782609  0.602740  0.571429  0.420290
# precision                  0.666667  0.782609  0.602740  0.571429  0.420290
# recall                     0.466667  0.514286  0.500000  0.500000  0.630435
# sensitivity                0.466667  0.514286  0.500000  0.500000  0.630435
# specificity                0.993476  0.995318  0.971429  0.997260  0.962157
# true_negative_rate         0.993476  0.995318  0.971429  0.997260  0.962157
# true_positive_rate         0.466667  0.514286  0.500000  0.500000  0.630435
#
#                                  NV  VASC  micro-average
# accuracy                   0.934723   1.0       0.967103
# f1                         0.959551   1.0       0.884859
# false_discovery_rate       0.047938   0.0       0.115141
# false_negative_rate        0.032843   0.0       0.115141
# false_positive_rate        0.195455   0.0       0.019190
# negative_predictive_value  0.859223   1.0       0.980810
# positive_predictive_value  0.952062   1.0       0.884859
# precision                  0.952062   1.0       0.884859
# recall                     0.967157   1.0       0.884859
# sensitivity                0.967157   1.0       0.884859
# specificity                0.804545   1.0       0.980810
# true_negative_rate         0.804545   1.0       0.980810
# true_positive_rate         0.967157   1.0       0.884859
